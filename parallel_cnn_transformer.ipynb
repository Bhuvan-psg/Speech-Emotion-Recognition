# %% [markdown]
# # Load the data

# %%
# This Python 3 environment comes with many helpful analytics libraries install|ed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np
import pandas as pd
import os
import librosa
import librosa.display
import IPython
from IPython.display import Audio
from IPython.display import Image
import matplotlib.pyplot as plt

EMOTIONS = {1:'neutral', 2:'calm', 3:'happy', 4:'sad', 5:'angry', 6:'fear', 7:'disgust', 0:'surprise'} # surprise je promenjen sa 8 na 0
DATA_PATH = 'E:/Bhuvan/Dataset'
SAMPLE_RATE = 48000

data = pd.DataFrame(columns=['Emotion', 'Emotion intensity', 'Gender','Path'])
for dirname, _, filenames in os.walk(DATA_PATH):
    for filename in filenames:
        file_path = os.path.join(dirname, filename)
        identifiers = filename.split('.')[0].split('-')
        emotion = (int(identifiers[2]))
        if emotion == 8: # promeni surprise sa 8 na 0
            emotion = 0
        if int(identifiers[3]) == 1:
            emotion_intensity = 'normal' 
        else:
            emotion_intensity = 'strong'
        if int(identifiers[6])%2 == 0:
            gender = 'female'
        else:
            gender = 'male'
        
        data = data.append({"Emotion": emotion,
                            "Emotion intensity": emotion_intensity,
                            "Gender": gender,
                            "Path": file_path
                             },
                             ignore_index = True
                          )
# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
print("number of files is {}".format(len(data)))
data.head()
# Out:
# number of files is 1440
#   Emotion Emotion intensity  Gender  \
# 0       1            normal    male
# 1       1            normal  female
# 2       1            normal    male
# 3       1            normal  female
# 4       1            normal    male
#
#                                          Path
# 0  E:/Bhuvan/Dataset\03-01-01-01-01-01-01.wav
# 1  E:/Bhuvan/Dataset\03-01-01-01-01-01-02.wav
# 2  E:/Bhuvan/Dataset\03-01-01-01-01-01-03.wav
# 3  E:/Bhuvan/Dataset\03-01-01-01-01-01-04.wav
# 4  E:/Bhuvan/Dataset\03-01-01-01-01-01-05.wav

# %% [markdown]
# Number of examples per emotion

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.bar(x=range(8), height=data['Emotion'].value_counts())
ax.set_xticks(ticks=range(8))
ax.set_xticklabels([EMOTIONS[i] for i in range(8)],fontsize=10)
ax.set_xlabel('Emotions')
ax.set_ylabel('Number of examples')
# Out:
# Text(0, 0.5, 'Number of examples')

# %% [markdown]
# number of examples per gender

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
counts = data['Gender'].value_counts()
ax.bar(x=[0,1], height=counts.values)
ax.set_xticks(ticks=[0,1])
ax.set_xticklabels(list(counts.index))
ax.set_xlabel('Gender')
ax.set_ylabel('Number of examples')
# Out:
# Text(0, 0.5, 'Number of examples')

# %% [markdown]
# number of examples per emotion intensity

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
counts = data['Emotion intensity'].value_counts()
ax.bar(x=[0,1], height=counts.values)
ax.set_xticks(ticks=[0,1])
ax.set_xticklabels(list(counts.index))
ax.set_xlabel('Gender')
ax.set_ylabel('Number of examples')
# Out:
# Text(0, 0.5, 'Number of examples')

# %% [markdown]
# # Load the signals

# %%
mel_spectrograms = []
signals = []
for i, file_path in enumerate(data.Path):
    audio, sample_rate = librosa.load(file_path, duration=3, offset=0.5, sr=SAMPLE_RATE)
    signal = np.zeros((int(SAMPLE_RATE*3,)))
    signal[:len(audio)] = audio
    signals.append(signal)
    print("\r Processed {}/{} files".format(i,len(data)),end='')
signals = np.stack(signals,axis=0)
# Out:
#  Processed 1439/1440 files

# %% [markdown]
# # Split the data

# %%
X = signals
train_ind,test_ind,val_ind = [],[],[]
X_train,X_val,X_test = [],[],[]
Y_train,Y_val,Y_test = [],[],[]
for emotion in range(len(EMOTIONS)):
    emotion_ind = list(data.loc[data.Emotion==emotion,'Emotion'].index)
    emotion_ind = np.random.permutation(emotion_ind)
    m = len(emotion_ind)
    ind_train = emotion_ind[:int(0.8*m)]
    ind_val = emotion_ind[int(0.8*m):int(0.9*m)]
    ind_test = emotion_ind[int(0.9*m):]
    X_train.append(X[ind_train,:])
    Y_train.append(np.array([emotion]*len(ind_train),dtype=np.int32))
    X_val.append(X[ind_val,:])
    Y_val.append(np.array([emotion]*len(ind_val),dtype=np.int32))
    X_test.append(X[ind_test,:])
    Y_test.append(np.array([emotion]*len(ind_test),dtype=np.int32))
    train_ind.append(ind_train)
    test_ind.append(ind_test)
    val_ind.append(ind_val)
X_train = np.concatenate(X_train,0)
X_val = np.concatenate(X_val,0)
X_test = np.concatenate(X_test,0)
Y_train = np.concatenate(Y_train,0)
Y_val = np.concatenate(Y_val,0)
Y_test = np.concatenate(Y_test,0)
train_ind = np.concatenate(train_ind,0)
val_ind = np.concatenate(val_ind,0)
test_ind = np.concatenate(test_ind,0)
print(f'X_train:{X_train.shape}, Y_train:{Y_train.shape}')
print(f'X_val:{X_val.shape}, Y_val:{Y_val.shape}')
print(f'X_test:{X_test.shape}, Y_test:{Y_test.shape}')
# check if all are unique
unique, count = np.unique(np.concatenate([train_ind,test_ind,val_ind],0), return_counts=True)
print("Number of unique indexes is {}, out of {}".format(sum(count==1), X.shape[0]))

del X
# Out:
# X_train:(1147, 144000), Y_train:(1147,)
# X_val:(143, 144000), Y_val:(143,)
# X_test:(150, 144000), Y_test:(150,)
# Number of unique indexes is 1440, out of 1440

# %% [markdown]
# # Augment signals by adding AWGN

# %%
def addAWGN(signal, num_bits=16, augmented_num=2, snr_low=15, snr_high=30): 
    signal_len = len(signal)
    # Generate White Gaussian noise
    noise = np.random.normal(size=(augmented_num, signal_len))
    # Normalize signal and noise
    norm_constant = 2.0**(num_bits-1)
    signal_norm = signal / norm_constant
    noise_norm = noise / norm_constant
    # Compute signal and noise power
    s_power = np.sum(signal_norm ** 2) / signal_len
    n_power = np.sum(noise_norm ** 2, axis=1) / signal_len
    # Random SNR: Uniform [15, 30] in dB
    target_snr = np.random.randint(snr_low, snr_high)
    # Compute K (covariance matrix) for each noise 
    K = np.sqrt((s_power / n_power) * 10 ** (- target_snr / 10))
    K = np.ones((signal_len, augmented_num)) * K  
    # Generate noisy signal
    return signal + K.T * noise

# %%
aug_signals = []
aug_labels = []
for i in range(X_train.shape[0]):
    signal = X_train[i,:]
    augmented_signals = addAWGN(signal)
    for j in range(augmented_signals.shape[0]):
        aug_labels.append(data.loc[i,"Emotion"])
        aug_signals.append(augmented_signals[j,:])
        data = data.append(data.iloc[i], ignore_index=True)
    print("\r Processed {}/{} files".format(i,X_train.shape[0]),end='')
aug_signals = np.stack(aug_signals,axis=0)
X_train = np.concatenate([X_train,aug_signals],axis=0)
aug_labels = np.stack(aug_labels,axis=0)
Y_train = np.concatenate([Y_train,aug_labels])
print('')
print(f'X_train:{X_train.shape}, Y_train:{Y_train.shape}')
# Out:
#  Processed 1146/1147 files
# X_train:(3441, 144000), Y_train:(3441,)

# %% [markdown]
# # Calculate mel spectrograms

# %%
def getMELspectrogram(audio, sample_rate):
    mel_spec = librosa.feature.melspectrogram(y=audio,
                                              sr=sample_rate,
                                              n_fft=1024,
                                              win_length = 512,
                                              window='hamming',
                                              hop_length = 256,
                                              n_mels=128,
                                              fmax=sample_rate/2
                                             )
    mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)
    return mel_spec_db

# test function
audio, sample_rate = librosa.load(data.loc[0,'Path'], duration=3, offset=0.5,sr=SAMPLE_RATE)
signal = np.zeros((int(SAMPLE_RATE*3,)))
signal[:len(audio)] = audio
mel_spectrogram = getMELspectrogram(signal, SAMPLE_RATE)
librosa.display.specshow(mel_spectrogram, y_axis='mel', x_axis='time')
print('MEL spectrogram shape: ',mel_spectrogram.shape)
# Out:
# MEL spectrogram shape:  (128, 563)

# %%
mel_train = []
print("Calculatin mel spectrograms for train set")
for i in range(X_train.shape[0]):
    mel_spectrogram = getMELspectrogram(X_train[i,:], sample_rate=SAMPLE_RATE)
    mel_train.append(mel_spectrogram)
    print("\r Processed {}/{} files".format(i,X_train.shape[0]),end='')
print('')
mel_train = np.stack(mel_train,axis=0)
del X_train
X_train = mel_train

mel_val = []
print("Calculatin mel spectrograms for val set")
for i in range(X_val.shape[0]):
    mel_spectrogram = getMELspectrogram(X_val[i,:], sample_rate=SAMPLE_RATE)
    mel_val.append(mel_spectrogram)
    print("\r Processed {}/{} files".format(i,X_val.shape[0]),end='')
print('')
mel_val = np.stack(mel_val,axis=0)
del X_val
X_val = mel_val

mel_test = []
print("Calculatin mel spectrograms for test set")
for i in range(X_test.shape[0]):
    mel_spectrogram = getMELspectrogram(X_test[i,:], sample_rate=SAMPLE_RATE)
    mel_test.append(mel_spectrogram)
    print("\r Processed {}/{} files".format(i,X_test.shape[0]),end='')
print('')
mel_test = np.stack(mel_test,axis=0)
del X_test
X_test = mel_test

print(f'X_train:{X_train.shape}, Y_train:{Y_train.shape}')
print(f'X_val:{X_val.shape}, Y_val:{Y_val.shape}')
print(f'X_test:{X_test.shape}, Y_test:{Y_test.shape}')
# Out:
# Calculatin mel spectrograms for train set
#  Processed 3440/3441 files
# Calculatin mel spectrograms for val set
#  Processed 142/143 files
# Calculatin mel spectrograms for test set
#  Processed 149/150 files
# X_train:(3441, 128, 563), Y_train:(3441,)
# X_val:(143, 128, 563), Y_val:(143,)
# X_test:(150, 128, 563), Y_test:(150,)

# %% [markdown]
# # Create the model

# %%
import torch
import torch.nn as nn

class ParallelModel(nn.Module):
    def __init__(self,num_emotions):
        super().__init__()
        # conv block
        self.conv2Dblock = nn.Sequential(
            # 1. conv block
            nn.Conv2d(in_channels=1,
                       out_channels=16,
                       kernel_size=3,
                       stride=1,
                       padding=1
                      ),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(p=0.3),
            # 2. conv block
            nn.Conv2d(in_channels=16,
                       out_channels=32,
                       kernel_size=3,
                       stride=1,
                       padding=1
                      ),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),
            # 3. conv block
            nn.Conv2d(in_channels=32,
                       out_channels=64,
                       kernel_size=3,
                       stride=1,
                       padding=1
                      ),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),
            # 4. conv block
            nn.Conv2d(in_channels=64,
                       out_channels=64,
                       kernel_size=3,
                       stride=1,
                       padding=1
                      ),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3)
        )
        # Transformer block
        self.transf_maxpool = nn.MaxPool2d(kernel_size=[2,4], stride=[2,4])
        transf_layer = nn.TransformerEncoderLayer(d_model=64, nhead=4, dim_feedforward=512, dropout=0.4, activation='relu')
        self.transf_encoder = nn.TransformerEncoder(transf_layer, num_layers=4)
        # Linear softmax layer
        self.out_linear = nn.Linear(320,num_emotions)
        self.dropout_linear = nn.Dropout(p=0)
        self.out_softmax = nn.Softmax(dim=1)
    def forward(self,x):
        # conv embedding
        conv_embedding = self.conv2Dblock(x) #(b,channel,freq,time)
        conv_embedding = torch.flatten(conv_embedding, start_dim=1) # do not flatten batch dimension
        # transformer embedding
        x_reduced = self.transf_maxpool(x)
        x_reduced = torch.squeeze(x_reduced,1)
        x_reduced = x_reduced.permute(2,0,1) # requires shape = (time,batch,embedding)
        transf_out = self.transf_encoder(x_reduced)
        transf_embedding = torch.mean(transf_out, dim=0)
        # concatenate
        complete_embedding = torch.cat([conv_embedding, transf_embedding], dim=1) 
        # final Linear
        output_logits = self.out_linear(complete_embedding)
        output_logits = self.dropout_linear(output_logits)
        output_softmax = self.out_softmax(output_logits)
        return output_logits, output_softmax

# %%
def loss_fnc(predictions, targets):
    return nn.CrossEntropyLoss()(input=predictions,target=targets)

# %% [markdown]
# # TRAINING

# %%
def make_train_step(model, loss_fnc, optimizer):
    def train_step(X,Y):
        # set model to train mode
        model.train()
        # forward pass
        output_logits, output_softmax = model(X)
        predictions = torch.argmax(output_softmax,dim=1)
        accuracy = torch.sum(Y==predictions)/float(len(Y))
        # compute loss
        loss = loss_fnc(output_logits, Y)
        # compute gradients
        loss.backward()
        # update parameters and zero gradients
        optimizer.step()
        optimizer.zero_grad()
        return loss.item(), accuracy*100
    return train_step

# %%
def make_validate_fnc(model,loss_fnc):
    def validate(X,Y):
        with torch.no_grad():
            model.eval()
            output_logits, output_softmax = model(X)
            predictions = torch.argmax(output_softmax,dim=1)
            accuracy = torch.sum(Y==predictions)/float(len(Y))
            loss = loss_fnc(output_logits,Y)
        return loss.item(), accuracy*100, predictions
    return validate

# %% [markdown]
# scale data

# %%
from sklearn.preprocessing import StandardScaler

X_train = np.expand_dims(X_train,1)
X_val = np.expand_dims(X_val,1)
X_test = np.expand_dims(X_test,1)

scaler = StandardScaler()

b,c,h,w = X_train.shape
X_train = np.reshape(X_train, newshape=(b,-1))
X_train = scaler.fit_transform(X_train)
X_train = np.reshape(X_train, newshape=(b,c,h,w))

b,c,h,w = X_test.shape
X_test = np.reshape(X_test, newshape=(b,-1))
X_test = scaler.transform(X_test)
X_test = np.reshape(X_test, newshape=(b,c,h,w))

b,c,h,w = X_val.shape
X_val = np.reshape(X_val, newshape=(b,-1))
X_val = scaler.transform(X_val)
X_val = np.reshape(X_val, newshape=(b,c,h,w))

# %% [markdown]
# Train the model

# %%
EPOCHS=500
DATASET_SIZE = X_train.shape[0]
BATCH_SIZE = 32
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('Selected device is {}'.format(device))
model = ParallelModel(num_emotions=len(EMOTIONS)).to(device)
print('Number of trainable params: ',sum(p.numel() for p in model.parameters()) )
OPTIMIZER = torch.optim.SGD(model.parameters(),lr=0.01, weight_decay=1e-3, momentum=0.8)

train_step = make_train_step(model, loss_fnc, optimizer=OPTIMIZER)
validate = make_validate_fnc(model,loss_fnc)
losses=[]
val_losses = []
acc_ep = []
vala = []
for epoch in range(EPOCHS):
    # schuffle data
    ind = np.random.permutation(DATASET_SIZE)
    X_train = X_train[ind,:,:,:]
    Y_train = Y_train[ind]
    epoch_acc = 0
    epoch_loss = 0
    iters = int(DATASET_SIZE / BATCH_SIZE)
    for i in range(iters):
        batch_start = i * BATCH_SIZE
        batch_end = min(batch_start + BATCH_SIZE, DATASET_SIZE)
        actual_batch_size = batch_end-batch_start
        X = X_train[batch_start:batch_end,:,:,:]
        Y = Y_train[batch_start:batch_end]
        X_tensor = torch.tensor(X,device=device).float()
        Y_tensor = torch.tensor(Y, dtype=torch.long,device=device)
        loss, acc = train_step(X_tensor,Y_tensor)
        epoch_acc += acc*actual_batch_size/DATASET_SIZE
        epoch_loss += loss*actual_batch_size/DATASET_SIZE
        print(f"\r Epoch {epoch}: iteration {i}/{iters}",end='')
    X_val_tensor = torch.tensor(X_val,device=device).float()
    Y_val_tensor = torch.tensor(Y_val,dtype=torch.long,device=device)
    val_loss, val_acc, predictions = validate(X_val_tensor,Y_val_tensor)
    losses.append(epoch_loss)
    val_losses.append(val_loss)
    acc_ep.append(epoch_acc)
    vala.append(val_acc)
    print('')
    print(f"Epoch {epoch} --> loss:{epoch_loss:.4f}, acc:{epoch_acc:.2f}%, val_loss:{val_loss:.4f}, val_acc:{val_acc:.2f}%")
# Out:
# Selected device is cuda
# Number of trainable params:  395176
#  Epoch 0: iteration 106/107
# Epoch 0 --> loss:2.0719, acc:22.17%, val_loss:2.3112, val_acc:18.88%
#  Epoch 1: iteration 106/107
# Epoch 1 --> loss:1.8299, acc:28.83%, val_loss:2.0547, val_acc:30.77%
#  Epoch 2: iteration 106/107
# Epoch 2 --> loss:1.7438, acc:32.55%, val_loss:1.9780, val_acc:34.27%
#  Epoch 3: iteration 106/107
# Epoch 3 --> loss:1.6727, acc:35.51%, val_loss:1.8427, val_acc:31.47%
#  Epoch 4: iteration 106/107
# Epoch 4 --> loss:1.6215, acc:37.52%, val_loss:1.9076, val_acc:32.87%
#  Epoch 5: iteration 106/107
# Epoch 5 --> loss:1.5880, acc:38.04%, val_loss:1.7142, val_acc:37.76%
#  Epoch 6: iteration 106/107
# Epoch 6 --> loss:1.5404, acc:40.19%, val_loss:1.6399, val_acc:41.26%
#  Epoch 7: iteration 106/107
# Epoch 7 --> loss:1.5027, acc:41.33%, val_loss:1.7456, val_acc:34.97%
#  Epoch 8: iteration 106/107
# Epoch 8 --> loss:1.4714, acc:43.36%, val_loss:1.8874, val_acc:35.66%
#  Epoch 9: iteration 106/107
# Epoch 9 --> loss:1.4234, acc:44.58%, val_loss:1.8626, val_acc:39.86%
#  Epoch 10: iteration 106/107
# Epoch 10 --> loss:1.3978, acc:46.35%, val_loss:1.5174, val_acc:43.36%
#  Epoch 11: iteration 106/107
# Epoch 11 --> loss:1.3863, acc:46.12%, val_loss:1.3964, val_acc:52.45%
#  Epoch 12: iteration 106/107
# Epoch 12 --> loss:1.3427, acc:49.38%, val_loss:1.3614, val_acc:50.35%
#  Epoch 13: iteration 106/107
# Epoch 13 --> loss:1.3375, acc:48.59%, val_loss:1.4758, val_acc:44.06%
#  Epoch 14: iteration 106/107
# Epoch 14 --> loss:1.2817, acc:50.25%, val_loss:1.2525, val_acc:54.55%
#  Epoch 15: iteration 106/107
# Epoch 15 --> loss:1.2596, acc:50.86%, val_loss:1.3006, val_acc:53.85%
#  Epoch 16: iteration 106/107
# Epoch 16 --> loss:1.2389, acc:53.12%, val_loss:1.2739, val_acc:54.55%
#  Epoch 17: iteration 106/107
# Epoch 17 --> loss:1.2226, acc:52.54%, val_loss:1.2203, val_acc:53.85%
#  Epoch 18: iteration 106/107
# Epoch 18 --> loss:1.1926, acc:54.03%, val_loss:1.3826, val_acc:51.75%
#  Epoch 19: iteration 106/107
# Epoch 19 --> loss:1.1538, acc:56.03%, val_loss:1.2538, val_acc:55.94%
#  Epoch 20: iteration 106/107
# Epoch 20 --> loss:1.1300, acc:56.47%, val_loss:1.2013, val_acc:60.14%
#  Epoch 21: iteration 106/107
# Epoch 21 --> loss:1.1094, acc:57.19%, val_loss:1.1703, val_acc:54.55%
#  Epoch 22: iteration 106/107
# Epoch 22 --> loss:1.0664, acc:59.34%, val_loss:1.1209, val_acc:60.14%
#  Epoch 23: iteration 106/107
# Epoch 23 --> loss:1.0450, acc:60.10%, val_loss:1.1316, val_acc:53.85%
#  Epoch 24: iteration 106/107
# Epoch 24 --> loss:1.0583, acc:59.52%, val_loss:1.1968, val_acc:55.94%
#  Epoch 25: iteration 106/107
# Epoch 25 --> loss:0.9793, acc:61.73%, val_loss:1.1644, val_acc:62.24%
#  Epoch 26: iteration 106/107
# Epoch 26 --> loss:0.9715, acc:62.74%, val_loss:1.1588, val_acc:58.04%
#  Epoch 27: iteration 106/107
# Epoch 27 --> loss:0.9731, acc:62.63%, val_loss:1.1676, val_acc:60.14%
#  Epoch 28: iteration 106/107
# Epoch 28 --> loss:0.9339, acc:63.88%, val_loss:1.2341, val_acc:55.24%
#  Epoch 29: iteration 106/107
# Epoch 29 --> loss:0.9261, acc:64.17%, val_loss:1.2495, val_acc:58.04%
#  Epoch 30: iteration 106/107
# Epoch 30 --> loss:0.9032, acc:64.63%, val_loss:1.1612, val_acc:60.14%
#  Epoch 31: iteration 106/107
# Epoch 31 --> loss:0.8910, acc:65.56%, val_loss:1.2058, val_acc:58.04%
#  Epoch 32: iteration 106/107
# Epoch 32 --> loss:0.8368, acc:67.89%, val_loss:1.0207, val_acc:60.84%
#  Epoch 33: iteration 106/107
# Epoch 33 --> loss:0.8156, acc:69.49%, val_loss:1.1040, val_acc:60.14%
#  Epoch 34: iteration 106/107
# Epoch 34 --> loss:0.7900, acc:69.25%, val_loss:1.0329, val_acc:62.94%
#  Epoch 35: iteration 106/107
# Epoch 35 --> loss:0.7959, acc:68.90%, val_loss:1.1064, val_acc:65.03%
#  Epoch 36: iteration 106/107
# Epoch 36 --> loss:0.7299, acc:72.39%, val_loss:1.2225, val_acc:61.54%
#  Epoch 37: iteration 106/107
# Epoch 37 --> loss:0.7318, acc:72.10%, val_loss:1.0657, val_acc:72.03%
#  Epoch 38: iteration 106/107
# Epoch 38 --> loss:0.7095, acc:72.36%, val_loss:1.4310, val_acc:58.74%
#  Epoch 39: iteration 106/107
# Epoch 39 --> loss:0.7055, acc:72.80%, val_loss:1.2131, val_acc:66.43%
#  Epoch 40: iteration 106/107
# Epoch 40 --> loss:0.6588, acc:74.08%, val_loss:1.0748, val_acc:62.94%
#  Epoch 41: iteration 106/107
# Epoch 41 --> loss:0.6841, acc:74.05%, val_loss:1.2207, val_acc:64.34%
#  Epoch 42: iteration 106/107
# Epoch 42 --> loss:0.6792, acc:74.11%, val_loss:1.2218, val_acc:65.73%
#  Epoch 43: iteration 106/107
# Epoch 43 --> loss:0.6535, acc:75.44%, val_loss:1.1726, val_acc:62.94%
#  Epoch 44: iteration 106/107
# Epoch 44 --> loss:0.6032, acc:76.66%, val_loss:1.1214, val_acc:67.13%
#  Epoch 45: iteration 106/107
# Epoch 45 --> loss:0.6299, acc:76.26%, val_loss:1.0543, val_acc:66.43%
#  Epoch 46: iteration 106/107
# Epoch 46 --> loss:0.5951, acc:77.54%, val_loss:1.0336, val_acc:63.64%
#  Epoch 47: iteration 106/107
# Epoch 47 --> loss:0.5980, acc:76.90%, val_loss:0.9675, val_acc:70.63%
#  Epoch 48: iteration 106/107
# Epoch 48 --> loss:0.5485, acc:78.90%, val_loss:1.1442, val_acc:65.73%
#  Epoch 49: iteration 106/107
# Epoch 49 --> loss:0.6111, acc:75.62%, val_loss:1.1634, val_acc:62.94%
#  Epoch 50: iteration 106/107
# Epoch 50 --> loss:0.5594, acc:78.52%, val_loss:1.2374, val_acc:63.64%
#  Epoch 51: iteration 106/107
# Epoch 51 --> loss:0.5127, acc:80.65%, val_loss:0.8860, val_acc:72.73%
#  Epoch 52: iteration 106/107
# Epoch 52 --> loss:0.5683, acc:78.35%, val_loss:0.9920, val_acc:67.13%
#  Epoch 53: iteration 106/107
# Epoch 53 --> loss:0.4868, acc:81.26%, val_loss:1.2873, val_acc:65.03%
#  Epoch 54: iteration 106/107
# Epoch 54 --> loss:0.5144, acc:80.59%, val_loss:1.1492, val_acc:72.03%
#  Epoch 55: iteration 106/107
# Epoch 55 --> loss:0.4681, acc:81.37%, val_loss:1.1419, val_acc:67.13%
#  Epoch 56: iteration 106/107
# Epoch 56 --> loss:0.4694, acc:81.23%, val_loss:1.0923, val_acc:67.13%
#  Epoch 57: iteration 106/107
# Epoch 57 --> loss:0.4674, acc:81.49%, val_loss:1.1801, val_acc:71.33%
#  Epoch 58: iteration 106/107
# Epoch 58 --> loss:0.4607, acc:83.14%, val_loss:1.2016, val_acc:68.53%
#  Epoch 59: iteration 106/107
# Epoch 59 --> loss:0.4428, acc:82.68%, val_loss:1.3462, val_acc:69.23%
#  Epoch 60: iteration 106/107
# Epoch 60 --> loss:0.4400, acc:83.03%, val_loss:1.1929, val_acc:65.73%
#  Epoch 61: iteration 106/107
# Epoch 61 --> loss:0.4136, acc:84.57%, val_loss:1.1060, val_acc:67.83%
#  Epoch 62: iteration 106/107
# Epoch 62 --> loss:0.4227, acc:83.70%, val_loss:1.1528, val_acc:70.63%
#  Epoch 63: iteration 106/107
# Epoch 63 --> loss:0.3902, acc:85.15%, val_loss:1.4456, val_acc:62.24%
#  Epoch 64: iteration 106/107
# Epoch 64 --> loss:0.4247, acc:83.70%, val_loss:1.3394, val_acc:55.94%
#  Epoch 65: iteration 106/107
# Epoch 65 --> loss:0.4020, acc:84.86%, val_loss:1.0842, val_acc:70.63%
#  Epoch 66: iteration 106/107
# Epoch 66 --> loss:0.3950, acc:85.12%, val_loss:1.2388, val_acc:66.43%
#  Epoch 67: iteration 106/107
# Epoch 67 --> loss:0.3356, acc:87.62%, val_loss:0.9662, val_acc:69.93%
#  Epoch 68: iteration 106/107
# Epoch 68 --> loss:0.3356, acc:87.39%, val_loss:1.2097, val_acc:66.43%
#  Epoch 69: iteration 106/107
# Epoch 69 --> loss:0.3545, acc:86.17%, val_loss:1.2089, val_acc:68.53%
#  Epoch 70: iteration 106/107
# Epoch 70 --> loss:0.3719, acc:85.59%, val_loss:1.2077, val_acc:68.53%
#  Epoch 71: iteration 106/107
# Epoch 71 --> loss:0.3850, acc:84.48%, val_loss:1.4833, val_acc:61.54%
#  Epoch 72: iteration 106/107
# Epoch 72 --> loss:0.2862, acc:89.28%, val_loss:1.3091, val_acc:66.43%
#  Epoch 73: iteration 106/107
# Epoch 73 --> loss:0.3597, acc:86.31%, val_loss:1.0024, val_acc:74.13%
#  Epoch 74: iteration 106/107
# Epoch 74 --> loss:0.2905, acc:89.01%, val_loss:1.1958, val_acc:67.13%
#  Epoch 75: iteration 106/107
# Epoch 75 --> loss:0.3378, acc:87.71%, val_loss:1.3842, val_acc:62.24%
#  Epoch 76: iteration 106/107
# Epoch 76 --> loss:0.3226, acc:87.97%, val_loss:1.2377, val_acc:68.53%
#  Epoch 77: iteration 106/107
# Epoch 77 --> loss:0.3002, acc:88.52%, val_loss:1.2754, val_acc:65.73%
#  Epoch 78: iteration 106/107
# Epoch 78 --> loss:0.2867, acc:88.84%, val_loss:1.6825, val_acc:58.04%
#  Epoch 79: iteration 106/107
# Epoch 79 --> loss:0.3121, acc:88.26%, val_loss:1.1913, val_acc:67.13%
#  Epoch 80: iteration 106/107
# Epoch 80 --> loss:0.2683, acc:90.03%, val_loss:1.0379, val_acc:70.63%
#  Epoch 81: iteration 106/107
# Epoch 81 --> loss:0.2648, acc:90.03%, val_loss:1.2024, val_acc:69.23%
#  Epoch 82: iteration 106/107
# Epoch 82 --> loss:0.2917, acc:88.64%, val_loss:1.1756, val_acc:74.13%
#  Epoch 83: iteration 106/107
# Epoch 83 --> loss:0.2583, acc:90.44%, val_loss:1.1194, val_acc:67.83%
#  Epoch 84: iteration 106/107
# Epoch 84 --> loss:0.3010, acc:88.11%, val_loss:1.5097, val_acc:65.73%
#  Epoch 85: iteration 106/107
# Epoch 85 --> loss:0.2412, acc:91.22%, val_loss:1.1655, val_acc:71.33%
#  Epoch 86: iteration 106/107
# Epoch 86 --> loss:0.2356, acc:91.66%, val_loss:1.6599, val_acc:65.03%
#  Epoch 87: iteration 106/107
# Epoch 87 --> loss:0.2723, acc:88.81%, val_loss:1.4460, val_acc:69.93%
#  Epoch 88: iteration 106/107
# Epoch 88 --> loss:0.2370, acc:90.79%, val_loss:1.1973, val_acc:69.93%
#  Epoch 89: iteration 106/107
# Epoch 89 --> loss:0.2402, acc:90.85%, val_loss:1.3218, val_acc:67.83%
#  Epoch 90: iteration 106/107
# Epoch 90 --> loss:0.2666, acc:89.54%, val_loss:1.2388, val_acc:67.13%
#  Epoch 91: iteration 106/107
# Epoch 91 --> loss:0.2261, acc:91.37%, val_loss:0.9981, val_acc:72.03%
#  Epoch 92: iteration 106/107
# Epoch 92 --> loss:0.2236, acc:91.40%, val_loss:1.3473, val_acc:72.73%
#  Epoch 93: iteration 106/107
# Epoch 93 --> loss:0.1868, acc:93.05%, val_loss:1.2728, val_acc:69.93%
#  Epoch 94: iteration 106/107
# Epoch 94 --> loss:0.3095, acc:87.97%, val_loss:1.1559, val_acc:74.13%
#  Epoch 95: iteration 106/107
# Epoch 95 --> loss:0.2506, acc:90.76%, val_loss:1.2102, val_acc:71.33%
#  Epoch 96: iteration 106/107
# Epoch 96 --> loss:0.2126, acc:91.95%, val_loss:1.5099, val_acc:67.13%
#  Epoch 97: iteration 106/107
# Epoch 97 --> loss:0.2337, acc:91.22%, val_loss:1.2860, val_acc:65.73%
#  Epoch 98: iteration 106/107
# Epoch 98 --> loss:0.1818, acc:93.35%, val_loss:1.1588, val_acc:72.73%
#  Epoch 99: iteration 106/107
# Epoch 99 --> loss:0.1909, acc:92.85%, val_loss:1.3685, val_acc:67.13%
#  Epoch 100: iteration 106/107
# Epoch 100 --> loss:0.1985, acc:92.39%, val_loss:1.4943, val_acc:62.94%
#  Epoch 101: iteration 106/107
# Epoch 101 --> loss:0.1722, acc:93.64%, val_loss:1.1190, val_acc:71.33%
#  Epoch 102: iteration 106/107
# Epoch 102 --> loss:0.1664, acc:93.64%, val_loss:1.3004, val_acc:67.83%
#  Epoch 103: iteration 106/107
# Epoch 103 --> loss:0.2182, acc:91.49%, val_loss:1.7385, val_acc:64.34%
#  Epoch 104: iteration 106/107
# Epoch 104 --> loss:0.2143, acc:91.89%, val_loss:1.1317, val_acc:69.23%
#  Epoch 105: iteration 106/107
# Epoch 105 --> loss:0.1497, acc:94.33%, val_loss:1.3080, val_acc:74.13%
#  Epoch 106: iteration 106/107
# Epoch 106 --> loss:0.2656, acc:90.21%, val_loss:1.5855, val_acc:67.83%
#  Epoch 107: iteration 106/107
# Epoch 107 --> loss:0.1902, acc:92.88%, val_loss:1.0710, val_acc:70.63%
#  Epoch 108: iteration 106/107
# Epoch 108 --> loss:0.1437, acc:95.03%, val_loss:1.0952, val_acc:71.33%
#  Epoch 109: iteration 106/107
# Epoch 109 --> loss:0.2143, acc:91.25%, val_loss:1.2984, val_acc:71.33%
#  Epoch 110: iteration 106/107
# Epoch 110 --> loss:0.1680, acc:93.78%, val_loss:1.1082, val_acc:72.73%
#  Epoch 111: iteration 106/107
# Epoch 111 --> loss:0.1749, acc:93.11%, val_loss:1.1751, val_acc:72.73%
#  Epoch 112: iteration 106/107
# Epoch 112 --> loss:0.1520, acc:94.33%, val_loss:1.4812, val_acc:68.53%
#  Epoch 113: iteration 106/107
# Epoch 113 --> loss:0.1184, acc:95.41%, val_loss:1.1118, val_acc:73.43%
#  Epoch 114: iteration 106/107
# Epoch 114 --> loss:0.1272, acc:95.15%, val_loss:1.2502, val_acc:69.93%
#  Epoch 115: iteration 106/107
# Epoch 115 --> loss:0.1725, acc:93.61%, val_loss:1.1936, val_acc:72.03%
#  Epoch 116: iteration 106/107
# Epoch 116 --> loss:0.2226, acc:92.30%, val_loss:1.3197, val_acc:68.53%
#  Epoch 117: iteration 106/107
# Epoch 117 --> loss:0.2600, acc:90.21%, val_loss:1.1696, val_acc:68.53%
#  Epoch 118: iteration 106/107
# Epoch 118 --> loss:0.1818, acc:92.94%, val_loss:1.3291, val_acc:67.13%
#  Epoch 119: iteration 106/107
# Epoch 119 --> loss:0.2132, acc:91.98%, val_loss:1.1466, val_acc:70.63%
#  Epoch 120: iteration 106/107
# Epoch 120 --> loss:0.1602, acc:94.62%, val_loss:1.1282, val_acc:71.33%
#  Epoch 121: iteration 106/107
# Epoch 121 --> loss:0.1107, acc:96.25%, val_loss:1.2035, val_acc:74.13%
#  Epoch 122: iteration 106/107
# Epoch 122 --> loss:0.1170, acc:95.82%, val_loss:0.9923, val_acc:71.33%
#  Epoch 123: iteration 106/107
# Epoch 123 --> loss:0.1328, acc:94.94%, val_loss:1.1805, val_acc:68.53%
#  Epoch 124: iteration 106/107
# Epoch 124 --> loss:0.1788, acc:93.35%, val_loss:1.3685, val_acc:69.93%
#  Epoch 125: iteration 106/107
# Epoch 125 --> loss:0.1605, acc:93.87%, val_loss:1.0560, val_acc:73.43%
#  Epoch 126: iteration 106/107
# Epoch 126 --> loss:0.1322, acc:94.68%, val_loss:1.2716, val_acc:74.13%
#  Epoch 127: iteration 106/107
# Epoch 127 --> loss:0.1316, acc:95.06%, val_loss:1.3666, val_acc:69.93%
#  Epoch 128: iteration 106/107
# Epoch 128 --> loss:0.1778, acc:93.43%, val_loss:1.1782, val_acc:71.33%
#  Epoch 129: iteration 106/107
# Epoch 129 --> loss:0.1154, acc:95.99%, val_loss:1.0000, val_acc:74.83%
#  Epoch 130: iteration 106/107
# Epoch 130 --> loss:0.1190, acc:96.08%, val_loss:1.2339, val_acc:72.73%
#  Epoch 131: iteration 106/107
# Epoch 131 --> loss:0.1285, acc:95.18%, val_loss:1.2536, val_acc:71.33%
#  Epoch 132: iteration 106/107
# Epoch 132 --> loss:0.1754, acc:93.35%, val_loss:1.4239, val_acc:67.13%
#  Epoch 133: iteration 106/107
# Epoch 133 --> loss:0.1226, acc:95.41%, val_loss:1.2399, val_acc:73.43%
#  Epoch 134: iteration 106/107
# Epoch 134 --> loss:0.0880, acc:97.01%, val_loss:1.2464, val_acc:67.83%
#  Epoch 135: iteration 106/107
# Epoch 135 --> loss:0.1791, acc:93.17%, val_loss:1.2592, val_acc:70.63%
#  Epoch 136: iteration 106/107
# Epoch 136 --> loss:0.2291, acc:91.34%, val_loss:1.9223, val_acc:60.14%
#  Epoch 137: iteration 106/107
# Epoch 137 --> loss:0.1808, acc:93.11%, val_loss:1.2048, val_acc:69.93%
#  Epoch 138: iteration 106/107
# Epoch 138 --> loss:0.1048, acc:96.02%, val_loss:1.0393, val_acc:73.43%
#  Epoch 139: iteration 106/107
# Epoch 139 --> loss:0.1043, acc:96.19%, val_loss:1.2611, val_acc:69.93%
#  Epoch 140: iteration 106/107
# Epoch 140 --> loss:0.1750, acc:93.96%, val_loss:1.0741, val_acc:74.13%
#  Epoch 141: iteration 106/107
# Epoch 141 --> loss:0.0880, acc:96.80%, val_loss:1.0741, val_acc:74.13%
#  Epoch 142: iteration 106/107
# Epoch 142 --> loss:0.1298, acc:95.03%, val_loss:1.5938, val_acc:62.24%
#  Epoch 143: iteration 106/107
# Epoch 143 --> loss:0.0674, acc:97.82%, val_loss:1.1243, val_acc:71.33%
#  Epoch 144: iteration 106/107
# Epoch 144 --> loss:0.0849, acc:97.15%, val_loss:1.9292, val_acc:64.34%
#  Epoch 145: iteration 106/107
# Epoch 145 --> loss:0.1501, acc:94.68%, val_loss:1.3529, val_acc:69.93%
#  Epoch 146: iteration 106/107
# Epoch 146 --> loss:0.1274, acc:95.47%, val_loss:1.2942, val_acc:70.63%
#  Epoch 147: iteration 106/107
# Epoch 147 --> loss:0.1393, acc:94.77%, val_loss:1.3329, val_acc:70.63%
#  Epoch 148: iteration 106/107
# Epoch 148 --> loss:0.1136, acc:95.67%, val_loss:1.3680, val_acc:67.13%
#  Epoch 149: iteration 106/107
# Epoch 149 --> loss:0.1602, acc:94.22%, val_loss:1.2135, val_acc:68.53%
#  Epoch 150: iteration 106/107
# Epoch 150 --> loss:0.1179, acc:95.32%, val_loss:0.9758, val_acc:74.83%
#  Epoch 151: iteration 106/107
# Epoch 151 --> loss:0.0949, acc:96.69%, val_loss:1.0973, val_acc:72.73%
#  Epoch 152: iteration 106/107
# Epoch 152 --> loss:0.1070, acc:95.87%, val_loss:1.1963, val_acc:71.33%
#  Epoch 153: iteration 106/107
# Epoch 153 --> loss:0.1468, acc:94.13%, val_loss:1.1597, val_acc:69.23%
#  Epoch 154: iteration 106/107
# Epoch 154 --> loss:0.1436, acc:94.71%, val_loss:1.5627, val_acc:67.83%
#  Epoch 155: iteration 106/107
# Epoch 155 --> loss:0.2011, acc:93.05%, val_loss:1.3760, val_acc:69.93%
#  Epoch 156: iteration 106/107
# Epoch 156 --> loss:0.1256, acc:95.58%, val_loss:1.1786, val_acc:70.63%
#  Epoch 157: iteration 106/107
# Epoch 157 --> loss:0.0584, acc:98.20%, val_loss:1.2408, val_acc:71.33%
#  Epoch 158: iteration 106/107
# Epoch 158 --> loss:0.0501, acc:98.29%, val_loss:1.1001, val_acc:72.73%
#  Epoch 159: iteration 106/107
# Epoch 159 --> loss:0.0792, acc:97.01%, val_loss:1.4157, val_acc:67.83%
#  Epoch 160: iteration 106/107
# Epoch 160 --> loss:0.1704, acc:93.37%, val_loss:1.4324, val_acc:71.33%
#  Epoch 161: iteration 106/107
# Epoch 161 --> loss:0.1531, acc:94.22%, val_loss:1.1107, val_acc:73.43%
#  Epoch 162: iteration 106/107
# Epoch 162 --> loss:0.1021, acc:95.93%, val_loss:1.2773, val_acc:67.83%
#  Epoch 163: iteration 106/107
# Epoch 163 --> loss:0.1245, acc:95.35%, val_loss:1.2916, val_acc:65.73%
#  Epoch 164: iteration 106/107
# Epoch 164 --> loss:0.2507, acc:90.87%, val_loss:1.5414, val_acc:65.03%
#  Epoch 165: iteration 106/107
# Epoch 165 --> loss:0.0850, acc:97.01%, val_loss:1.0530, val_acc:70.63%
#  Epoch 166: iteration 106/107
# Epoch 166 --> loss:0.1295, acc:95.09%, val_loss:1.2681, val_acc:67.83%
#  Epoch 167: iteration 106/107
# Epoch 167 --> loss:0.0899, acc:96.40%, val_loss:1.3164, val_acc:72.03%
#  Epoch 168: iteration 106/107
# Epoch 168 --> loss:0.0590, acc:97.79%, val_loss:1.1762, val_acc:71.33%
#  Epoch 169: iteration 106/107
# Epoch 169 --> loss:0.0473, acc:98.46%, val_loss:1.1340, val_acc:73.43%
#  Epoch 170: iteration 106/107
# Epoch 170 --> loss:0.0464, acc:98.31%, val_loss:1.0457, val_acc:78.32%
#  Epoch 171: iteration 106/107
# Epoch 171 --> loss:0.0510, acc:98.37%, val_loss:1.1941, val_acc:73.43%
#  Epoch 172: iteration 106/107
# Epoch 172 --> loss:0.0844, acc:96.92%, val_loss:1.1244, val_acc:69.93%
#  Epoch 173: iteration 106/107
# Epoch 173 --> loss:0.2227, acc:91.49%, val_loss:1.6604, val_acc:62.24%
#  Epoch 174: iteration 106/107
# Epoch 174 --> loss:0.1567, acc:93.96%, val_loss:1.2961, val_acc:73.43%
#  Epoch 175: iteration 106/107
# Epoch 175 --> loss:0.1465, acc:94.39%, val_loss:1.4707, val_acc:67.83%
#  Epoch 176: iteration 106/107
# Epoch 176 --> loss:0.0788, acc:97.27%, val_loss:1.2036, val_acc:72.03%
#  Epoch 177: iteration 106/107
# Epoch 177 --> loss:0.0614, acc:97.85%, val_loss:1.1884, val_acc:69.93%
#  Epoch 178: iteration 106/107
# Epoch 178 --> loss:0.0605, acc:97.62%, val_loss:1.2359, val_acc:72.73%
#  Epoch 179: iteration 106/107
# Epoch 179 --> loss:0.0592, acc:97.99%, val_loss:1.3185, val_acc:69.23%
#  Epoch 180: iteration 106/107
# Epoch 180 --> loss:0.0865, acc:96.77%, val_loss:1.7814, val_acc:65.73%
#  Epoch 181: iteration 106/107
# Epoch 181 --> loss:0.1236, acc:95.32%, val_loss:1.4441, val_acc:66.43%
#  Epoch 182: iteration 106/107
# Epoch 182 --> loss:0.0974, acc:96.31%, val_loss:1.2070, val_acc:70.63%
#  Epoch 183: iteration 106/107
# Epoch 183 --> loss:0.1302, acc:94.91%, val_loss:1.1599, val_acc:73.43%
#  Epoch 184: iteration 106/107
# Epoch 184 --> loss:0.2086, acc:91.80%, val_loss:1.4959, val_acc:69.23%
#  Epoch 185: iteration 106/107
# Epoch 185 --> loss:0.0999, acc:96.25%, val_loss:0.9940, val_acc:74.13%
#  Epoch 186: iteration 106/107
# Epoch 186 --> loss:0.0953, acc:96.60%, val_loss:1.1623, val_acc:77.62%
#  Epoch 187: iteration 106/107
# Epoch 187 --> loss:0.0554, acc:98.26%, val_loss:0.9673, val_acc:73.43%
#  Epoch 188: iteration 106/107
# Epoch 188 --> loss:0.0539, acc:98.31%, val_loss:1.3784, val_acc:71.33%
#  Epoch 189: iteration 106/107
# Epoch 189 --> loss:0.0726, acc:97.53%, val_loss:1.2468, val_acc:71.33%
#  Epoch 190: iteration 106/107
# Epoch 190 --> loss:0.2753, acc:90.21%, val_loss:1.4680, val_acc:62.94%
#  Epoch 191: iteration 106/107
# Epoch 191 --> loss:0.1709, acc:93.43%, val_loss:1.0422, val_acc:72.73%
#  Epoch 192: iteration 106/107
# Epoch 192 --> loss:0.1000, acc:96.08%, val_loss:1.1024, val_acc:74.13%
#  Epoch 193: iteration 106/107
# Epoch 193 --> loss:0.0676, acc:97.36%, val_loss:1.1197, val_acc:76.92%
#  Epoch 194: iteration 106/107
# Epoch 194 --> loss:0.0526, acc:98.17%, val_loss:1.3174, val_acc:69.93%
#  Epoch 195: iteration 106/107
# Epoch 195 --> loss:0.0408, acc:98.66%, val_loss:1.0259, val_acc:76.92%
#  Epoch 196: iteration 106/107
# Epoch 196 --> loss:0.0439, acc:98.23%, val_loss:0.9937, val_acc:76.22%
#  Epoch 197: iteration 106/107
# Epoch 197 --> loss:0.2501, acc:91.05%, val_loss:1.5132, val_acc:62.94%
#  Epoch 198: iteration 106/107
# Epoch 198 --> loss:0.1645, acc:94.22%, val_loss:0.9539, val_acc:73.43%
#  Epoch 199: iteration 106/107
# Epoch 199 --> loss:0.0476, acc:98.69%, val_loss:0.9644, val_acc:76.22%
#  Epoch 200: iteration 106/107
# Epoch 200 --> loss:0.0446, acc:98.55%, val_loss:1.2373, val_acc:70.63%
#  Epoch 201: iteration 106/107
# Epoch 201 --> loss:0.0467, acc:98.40%, val_loss:1.1271, val_acc:70.63%
#  Epoch 202: iteration 106/107
# Epoch 202 --> loss:0.0288, acc:99.13%, val_loss:1.1016, val_acc:74.13%
#  Epoch 203: iteration 106/107
# Epoch 203 --> loss:0.0904, acc:96.43%, val_loss:1.5936, val_acc:65.73%
#  Epoch 204: iteration 106/107
# Epoch 204 --> loss:0.1681, acc:93.69%, val_loss:1.6114, val_acc:60.14%
#  Epoch 205: iteration 106/107
# Epoch 205 --> loss:0.1081, acc:96.11%, val_loss:1.3339, val_acc:71.33%
#  Epoch 206: iteration 106/107
# Epoch 206 --> loss:0.0811, acc:97.18%, val_loss:1.3309, val_acc:72.73%
#  Epoch 207: iteration 106/107
# Epoch 207 --> loss:0.0798, acc:96.92%, val_loss:1.1926, val_acc:69.93%
#  Epoch 208: iteration 106/107
# Epoch 208 --> loss:0.2085, acc:92.33%, val_loss:1.2895, val_acc:72.03%
#  Epoch 209: iteration 106/107
# Epoch 209 --> loss:0.1665, acc:93.66%, val_loss:1.2230, val_acc:67.83%
#  Epoch 210: iteration 106/107
# Epoch 210 --> loss:0.1022, acc:96.37%, val_loss:1.2158, val_acc:68.53%
#  Epoch 211: iteration 106/107
# Epoch 211 --> loss:0.0880, acc:96.54%, val_loss:1.2491, val_acc:69.93%
#  Epoch 212: iteration 106/107
# Epoch 212 --> loss:0.0352, acc:98.63%, val_loss:1.0349, val_acc:74.13%
#  Epoch 213: iteration 106/107
# Epoch 213 --> loss:0.0258, acc:99.07%, val_loss:0.9919, val_acc:76.92%
#  Epoch 214: iteration 106/107
# Epoch 214 --> loss:0.0363, acc:98.52%, val_loss:1.0922, val_acc:72.73%
#  Epoch 215: iteration 106/107
# Epoch 215 --> loss:0.0394, acc:98.40%, val_loss:1.2440, val_acc:70.63%
#  Epoch 216: iteration 106/107
# Epoch 216 --> loss:0.0991, acc:96.66%, val_loss:1.5177, val_acc:64.34%
#  Epoch 217: iteration 106/107
# Epoch 217 --> loss:0.2395, acc:90.82%, val_loss:1.2227, val_acc:69.23%
#  Epoch 218: iteration 106/107
# Epoch 218 --> loss:0.0900, acc:96.63%, val_loss:1.8298, val_acc:58.04%
#  Epoch 219: iteration 106/107
# Epoch 219 --> loss:0.0873, acc:96.80%, val_loss:1.2382, val_acc:72.73%
#  Epoch 220: iteration 106/107
# Epoch 220 --> loss:0.0899, acc:96.77%, val_loss:1.5804, val_acc:62.24%
#  Epoch 221: iteration 106/107
# Epoch 221 --> loss:0.0504, acc:98.11%, val_loss:1.1454, val_acc:69.23%
#  Epoch 222: iteration 106/107
# Epoch 222 --> loss:0.1061, acc:96.19%, val_loss:1.3540, val_acc:69.93%
#  Epoch 223: iteration 106/107
# Epoch 223 --> loss:0.1490, acc:94.07%, val_loss:1.2058, val_acc:69.93%
#  Epoch 224: iteration 106/107
# Epoch 224 --> loss:0.1609, acc:93.69%, val_loss:1.2014, val_acc:72.03%
#  Epoch 225: iteration 106/107
# Epoch 225 --> loss:0.1044, acc:95.64%, val_loss:1.0593, val_acc:74.83%
#  Epoch 226: iteration 106/107
# Epoch 226 --> loss:0.1251, acc:95.09%, val_loss:1.1191, val_acc:72.03%
#  Epoch 227: iteration 106/107
# Epoch 227 --> loss:0.1112, acc:95.67%, val_loss:1.1991, val_acc:72.03%
#  Epoch 228: iteration 106/107
# Epoch 228 --> loss:0.0906, acc:96.57%, val_loss:1.5852, val_acc:63.64%
#  Epoch 229: iteration 106/107
# Epoch 229 --> loss:0.1243, acc:95.29%, val_loss:1.6736, val_acc:63.64%
#  Epoch 230: iteration 106/107
# Epoch 230 --> loss:0.1125, acc:95.79%, val_loss:1.3657, val_acc:68.53%
#  Epoch 231: iteration 106/107
# Epoch 231 --> loss:0.1042, acc:96.31%, val_loss:1.1338, val_acc:71.33%
#  Epoch 232: iteration 106/107
# Epoch 232 --> loss:0.1706, acc:93.55%, val_loss:1.9313, val_acc:58.74%
#  Epoch 233: iteration 106/107
# Epoch 233 --> loss:0.1270, acc:95.15%, val_loss:1.2543, val_acc:72.73%
#  Epoch 234: iteration 106/107
# Epoch 234 --> loss:0.0601, acc:97.79%, val_loss:0.9423, val_acc:72.73%
#  Epoch 235: iteration 106/107
# Epoch 235 --> loss:0.1824, acc:93.00%, val_loss:1.1829, val_acc:69.93%
#  Epoch 236: iteration 106/107
# Epoch 236 --> loss:0.0650, acc:97.65%, val_loss:1.0191, val_acc:75.52%
#  Epoch 237: iteration 106/107
# Epoch 237 --> loss:0.0513, acc:98.20%, val_loss:1.4953, val_acc:65.73%
#  Epoch 238: iteration 106/107
# Epoch 238 --> loss:0.0420, acc:98.63%, val_loss:0.9693, val_acc:74.13%
#  Epoch 239: iteration 106/107
# Epoch 239 --> loss:0.1192, acc:95.82%, val_loss:1.0015, val_acc:74.83%
#  Epoch 240: iteration 106/107
# Epoch 240 --> loss:0.0358, acc:98.81%, val_loss:1.1152, val_acc:72.03%
#  Epoch 241: iteration 106/107
# Epoch 241 --> loss:0.0496, acc:98.29%, val_loss:1.1342, val_acc:74.13%
#  Epoch 242: iteration 106/107
# Epoch 242 --> loss:0.0266, acc:99.04%, val_loss:1.3938, val_acc:69.23%
#  Epoch 243: iteration 106/107
# Epoch 243 --> loss:0.0347, acc:98.61%, val_loss:1.2973, val_acc:74.13%
#  Epoch 244: iteration 106/107
# Epoch 244 --> loss:0.0487, acc:98.14%, val_loss:1.1304, val_acc:74.83%
#  Epoch 245: iteration 106/107
# Epoch 245 --> loss:0.1862, acc:93.61%, val_loss:2.0686, val_acc:55.94%
#  Epoch 246: iteration 106/107
# Epoch 246 --> loss:0.2009, acc:92.56%, val_loss:1.3994, val_acc:64.34%
#  Epoch 247: iteration 106/107
# Epoch 247 --> loss:0.1720, acc:93.55%, val_loss:1.1778, val_acc:67.13%
#  Epoch 248: iteration 106/107
# Epoch 248 --> loss:0.0520, acc:98.58%, val_loss:0.9618, val_acc:73.43%
#  Epoch 249: iteration 106/107
# Epoch 249 --> loss:0.0333, acc:98.84%, val_loss:1.1480, val_acc:71.33%
#  Epoch 250: iteration 106/107
# Epoch 250 --> loss:0.0491, acc:98.05%, val_loss:1.1796, val_acc:73.43%
#  Epoch 251: iteration 106/107
# Epoch 251 --> loss:0.1028, acc:96.31%, val_loss:1.4722, val_acc:62.94%
#  Epoch 252: iteration 106/107
# Epoch 252 --> loss:0.0619, acc:97.62%, val_loss:0.9633, val_acc:79.02%
#  Epoch 253: iteration 106/107
# Epoch 253 --> loss:0.0409, acc:98.55%, val_loss:1.0426, val_acc:72.73%
#  Epoch 254: iteration 106/107
# Epoch 254 --> loss:0.0342, acc:98.81%, val_loss:1.0408, val_acc:78.32%
#  Epoch 255: iteration 106/107
# Epoch 255 --> loss:0.2469, acc:90.76%, val_loss:1.4857, val_acc:64.34%
#  Epoch 256: iteration 106/107
# Epoch 256 --> loss:0.1172, acc:95.79%, val_loss:1.1959, val_acc:67.83%
#  Epoch 257: iteration 106/107
# Epoch 257 --> loss:0.0671, acc:97.53%, val_loss:1.0967, val_acc:69.93%
#  Epoch 258: iteration 106/107
# Epoch 258 --> loss:0.0733, acc:97.15%, val_loss:1.1689, val_acc:69.23%
#  Epoch 259: iteration 106/107
# Epoch 259 --> loss:0.0743, acc:97.04%, val_loss:1.1032, val_acc:73.43%
#  Epoch 260: iteration 106/107
# Epoch 260 --> loss:0.1424, acc:94.30%, val_loss:1.7533, val_acc:64.34%
#  Epoch 261: iteration 106/107
# Epoch 261 --> loss:0.0812, acc:97.18%, val_loss:1.1743, val_acc:69.23%
#  Epoch 262: iteration 106/107
# Epoch 262 --> loss:0.0617, acc:97.68%, val_loss:1.4344, val_acc:65.73%
#  Epoch 263: iteration 106/107
# Epoch 263 --> loss:0.0905, acc:96.34%, val_loss:1.1209, val_acc:71.33%
#  Epoch 264: iteration 106/107
# Epoch 264 --> loss:0.1957, acc:92.47%, val_loss:1.2212, val_acc:69.23%
#  Epoch 265: iteration 106/107
# Epoch 265 --> loss:0.1000, acc:96.31%, val_loss:1.1300, val_acc:71.33%
#  Epoch 266: iteration 106/107
# Epoch 266 --> loss:0.1200, acc:95.20%, val_loss:1.0966, val_acc:73.43%
#  Epoch 267: iteration 106/107
# Epoch 267 --> loss:0.0780, acc:96.92%, val_loss:1.2603, val_acc:69.23%
#  Epoch 268: iteration 106/107
# Epoch 268 --> loss:0.0571, acc:97.94%, val_loss:1.4636, val_acc:66.43%
#  Epoch 269: iteration 106/107
# Epoch 269 --> loss:0.0526, acc:98.14%, val_loss:1.2518, val_acc:72.73%
#  Epoch 270: iteration 106/107
# Epoch 270 --> loss:0.0316, acc:98.90%, val_loss:1.1448, val_acc:73.43%
#  Epoch 271: iteration 106/107
# Epoch 271 --> loss:0.1423, acc:94.48%, val_loss:1.4338, val_acc:67.13%
#  Epoch 272: iteration 106/107
# Epoch 272 --> loss:0.2649, acc:90.50%, val_loss:1.2909, val_acc:69.23%
#  Epoch 273: iteration 106/107
# Epoch 273 --> loss:0.0835, acc:97.09%, val_loss:1.2526, val_acc:71.33%
#  Epoch 274: iteration 106/107
# Epoch 274 --> loss:0.0576, acc:97.88%, val_loss:0.9827, val_acc:73.43%
#  Epoch 275: iteration 106/107
# Epoch 275 --> loss:0.0628, acc:97.56%, val_loss:1.2225, val_acc:72.03%
#  Epoch 276: iteration 106/107
# Epoch 276 --> loss:0.0473, acc:98.23%, val_loss:0.9788, val_acc:74.13%
#  Epoch 277: iteration 106/107
# Epoch 277 --> loss:0.0693, acc:97.27%, val_loss:1.6098, val_acc:61.54%
#  Epoch 278: iteration 106/107
# Epoch 278 --> loss:0.0900, acc:96.83%, val_loss:1.2297, val_acc:72.73%
#  Epoch 279: iteration 106/107
# Epoch 279 --> loss:0.1076, acc:96.02%, val_loss:1.0496, val_acc:73.43%
#  Epoch 280: iteration 106/107
# Epoch 280 --> loss:0.1832, acc:92.68%, val_loss:1.6100, val_acc:62.94%
#  Epoch 281: iteration 106/107
# Epoch 281 --> loss:0.1271, acc:95.12%, val_loss:1.1108, val_acc:72.03%
#  Epoch 282: iteration 106/107
# Epoch 282 --> loss:0.1014, acc:96.31%, val_loss:1.3571, val_acc:65.03%
#  Epoch 283: iteration 106/107
# Epoch 283 --> loss:0.1267, acc:95.23%, val_loss:1.1209, val_acc:72.03%
#  Epoch 284: iteration 106/107
# Epoch 284 --> loss:0.0490, acc:98.05%, val_loss:1.3985, val_acc:67.13%
#  Epoch 285: iteration 106/107
# Epoch 285 --> loss:0.0577, acc:97.70%, val_loss:1.2122, val_acc:69.23%
#  Epoch 286: iteration 106/107
# Epoch 286 --> loss:0.0444, acc:98.40%, val_loss:1.0027, val_acc:74.13%
#  Epoch 287: iteration 106/107
# Epoch 287 --> loss:0.0403, acc:98.26%, val_loss:1.2960, val_acc:69.93%
#  Epoch 288: iteration 106/107
# Epoch 288 --> loss:0.1436, acc:94.10%, val_loss:1.1796, val_acc:72.73%
#  Epoch 289: iteration 106/107
# Epoch 289 --> loss:0.1988, acc:92.71%, val_loss:1.1579, val_acc:70.63%
#  Epoch 290: iteration 106/107
# Epoch 290 --> loss:0.0698, acc:97.47%, val_loss:1.1783, val_acc:70.63%
#  Epoch 291: iteration 106/107
# Epoch 291 --> loss:0.1421, acc:94.80%, val_loss:1.0859, val_acc:71.33%
#  Epoch 292: iteration 106/107
# Epoch 292 --> loss:0.0511, acc:98.08%, val_loss:0.9597, val_acc:72.73%
#  Epoch 293: iteration 106/107
# Epoch 293 --> loss:0.0320, acc:98.72%, val_loss:1.0134, val_acc:72.03%
#  Epoch 294: iteration 106/107
# Epoch 294 --> loss:0.0397, acc:98.61%, val_loss:1.3991, val_acc:66.43%
#  Epoch 295: iteration 106/107
# Epoch 295 --> loss:0.1677, acc:93.93%, val_loss:1.2697, val_acc:67.83%
#  Epoch 296: iteration 106/107
# Epoch 296 --> loss:0.1309, acc:95.00%, val_loss:1.5911, val_acc:67.83%
#  Epoch 297: iteration 106/107
# Epoch 297 --> loss:0.1024, acc:96.31%, val_loss:1.2988, val_acc:70.63%
#  Epoch 298: iteration 106/107
# Epoch 298 --> loss:0.0587, acc:97.85%, val_loss:1.0445, val_acc:74.13%
#  Epoch 299: iteration 106/107
# Epoch 299 --> loss:0.0638, acc:97.47%, val_loss:1.2868, val_acc:70.63%
#  Epoch 300: iteration 106/107
# Epoch 300 --> loss:0.0755, acc:97.12%, val_loss:1.1194, val_acc:67.13%
#  Epoch 301: iteration 106/107
# Epoch 301 --> loss:0.0917, acc:96.54%, val_loss:0.8959, val_acc:74.83%
#  Epoch 302: iteration 106/107
# Epoch 302 --> loss:0.0284, acc:98.95%, val_loss:1.0835, val_acc:71.33%
#  Epoch 303: iteration 106/107
# Epoch 303 --> loss:0.0247, acc:98.98%, val_loss:1.6137, val_acc:69.23%
#  Epoch 304: iteration 106/107
# Epoch 304 --> loss:0.1915, acc:92.79%, val_loss:1.2555, val_acc:65.73%
#  Epoch 305: iteration 106/107
# Epoch 305 --> loss:0.1479, acc:94.16%, val_loss:1.2766, val_acc:69.23%
#  Epoch 306: iteration 106/107
# Epoch 306 --> loss:0.0554, acc:97.85%, val_loss:1.0531, val_acc:71.33%
#  Epoch 307: iteration 106/107
# Epoch 307 --> loss:0.0418, acc:98.34%, val_loss:1.1461, val_acc:74.83%
#  Epoch 308: iteration 106/107
# Epoch 308 --> loss:0.0462, acc:98.31%, val_loss:1.1615, val_acc:72.73%
#  Epoch 309: iteration 106/107
# Epoch 309 --> loss:0.0597, acc:97.65%, val_loss:1.3723, val_acc:67.13%
#  Epoch 310: iteration 106/107
# Epoch 310 --> loss:0.0545, acc:97.85%, val_loss:1.1058, val_acc:73.43%
#  Epoch 311: iteration 106/107
# Epoch 311 --> loss:0.0258, acc:99.01%, val_loss:1.2282, val_acc:74.13%
#  Epoch 312: iteration 106/107
# Epoch 312 --> loss:0.2557, acc:91.63%, val_loss:1.3624, val_acc:69.93%
#  Epoch 313: iteration 106/107
# Epoch 313 --> loss:0.1117, acc:95.58%, val_loss:1.1630, val_acc:72.03%
#  Epoch 314: iteration 106/107
# Epoch 314 --> loss:0.0711, acc:97.15%, val_loss:1.2942, val_acc:66.43%
#  Epoch 315: iteration 106/107
# Epoch 315 --> loss:0.0468, acc:98.55%, val_loss:1.0129, val_acc:72.73%
#  Epoch 316: iteration 106/107
# Epoch 316 --> loss:0.0632, acc:97.47%, val_loss:1.3160, val_acc:69.23%
#  Epoch 317: iteration 106/107
# Epoch 317 --> loss:0.2537, acc:90.96%, val_loss:1.3845, val_acc:67.13%
#  Epoch 318: iteration 106/107
# Epoch 318 --> loss:0.0783, acc:97.01%, val_loss:1.1379, val_acc:69.93%
#  Epoch 319: iteration 106/107
# Epoch 319 --> loss:0.0349, acc:98.92%, val_loss:1.0709, val_acc:71.33%
#  Epoch 320: iteration 106/107
# Epoch 320 --> loss:0.0220, acc:99.24%, val_loss:1.1970, val_acc:70.63%
#  Epoch 321: iteration 106/107
# Epoch 321 --> loss:0.0186, acc:99.27%, val_loss:1.1035, val_acc:74.83%
#  Epoch 322: iteration 106/107
# Epoch 322 --> loss:0.0147, acc:99.36%, val_loss:1.0132, val_acc:76.92%
#  Epoch 323: iteration 106/107
# Epoch 323 --> loss:0.0520, acc:97.97%, val_loss:1.3176, val_acc:73.43%
#  Epoch 324: iteration 106/107
# Epoch 324 --> loss:0.1414, acc:94.57%, val_loss:1.3192, val_acc:67.83%
#  Epoch 325: iteration 106/107
# Epoch 325 --> loss:0.2015, acc:92.36%, val_loss:1.4549, val_acc:69.93%
#  Epoch 326: iteration 106/107
# Epoch 326 --> loss:0.1325, acc:94.97%, val_loss:1.1991, val_acc:74.13%
#  Epoch 327: iteration 106/107
# Epoch 327 --> loss:0.1054, acc:95.99%, val_loss:1.0044, val_acc:73.43%
#  Epoch 328: iteration 106/107
# Epoch 328 --> loss:0.0601, acc:97.82%, val_loss:1.0725, val_acc:72.03%
#  Epoch 329: iteration 106/107
# Epoch 329 --> loss:0.0401, acc:98.61%, val_loss:0.9811, val_acc:76.92%
#  Epoch 330: iteration 106/107
# Epoch 330 --> loss:0.0982, acc:96.31%, val_loss:1.0139, val_acc:74.13%
#  Epoch 331: iteration 106/107
# Epoch 331 --> loss:0.1399, acc:94.74%, val_loss:1.4061, val_acc:62.24%
#  Epoch 332: iteration 106/107
# Epoch 332 --> loss:0.1116, acc:95.84%, val_loss:1.2231, val_acc:71.33%
#  Epoch 333: iteration 106/107
# Epoch 333 --> loss:0.1134, acc:95.58%, val_loss:0.9734, val_acc:72.73%
#  Epoch 334: iteration 106/107
# Epoch 334 --> loss:0.0710, acc:97.12%, val_loss:1.2006, val_acc:71.33%
#  Epoch 335: iteration 106/107
# Epoch 335 --> loss:0.0445, acc:98.14%, val_loss:1.0520, val_acc:74.13%
#  Epoch 336: iteration 106/107
# Epoch 336 --> loss:0.0541, acc:97.73%, val_loss:1.8511, val_acc:60.84%
#  Epoch 337: iteration 106/107
# Epoch 337 --> loss:0.0396, acc:98.49%, val_loss:1.0635, val_acc:75.52%
#  Epoch 338: iteration 106/107
# Epoch 338 --> loss:0.0490, acc:98.14%, val_loss:1.1467, val_acc:71.33%
#  Epoch 339: iteration 106/107
# Epoch 339 --> loss:0.3070, acc:90.21%, val_loss:1.5216, val_acc:62.24%
#  Epoch 340: iteration 106/107
# Epoch 340 --> loss:0.1578, acc:94.01%, val_loss:1.1855, val_acc:69.93%
#  Epoch 341: iteration 106/107
# Epoch 341 --> loss:0.0407, acc:98.63%, val_loss:0.9013, val_acc:75.52%
#  Epoch 342: iteration 106/107
# Epoch 342 --> loss:0.0209, acc:99.33%, val_loss:1.0633, val_acc:75.52%
#  Epoch 343: iteration 106/107
# Epoch 343 --> loss:0.0217, acc:99.19%, val_loss:1.0248, val_acc:74.13%
#  Epoch 344: iteration 106/107
# Epoch 344 --> loss:0.0785, acc:96.86%, val_loss:1.2326, val_acc:70.63%
#  Epoch 345: iteration 106/107
# Epoch 345 --> loss:0.0961, acc:96.45%, val_loss:1.1292, val_acc:71.33%
#  Epoch 346: iteration 106/107
# Epoch 346 --> loss:0.0873, acc:96.63%, val_loss:1.5963, val_acc:65.03%
#  Epoch 347: iteration 106/107
# Epoch 347 --> loss:0.0850, acc:96.89%, val_loss:1.1083, val_acc:73.43%
#  Epoch 348: iteration 106/107
# Epoch 348 --> loss:0.0592, acc:97.65%, val_loss:1.2622, val_acc:73.43%
#  Epoch 349: iteration 106/107
# Epoch 349 --> loss:0.0469, acc:98.17%, val_loss:1.0552, val_acc:76.22%
#  Epoch 350: iteration 106/107
# Epoch 350 --> loss:0.0285, acc:98.81%, val_loss:1.2831, val_acc:70.63%
#  Epoch 351: iteration 106/107
# Epoch 351 --> loss:0.0684, acc:97.47%, val_loss:1.0911, val_acc:72.73%
#  Epoch 352: iteration 106/107
# Epoch 352 --> loss:0.1062, acc:96.08%, val_loss:1.2667, val_acc:71.33%
#  Epoch 353: iteration 106/107
# Epoch 353 --> loss:0.1843, acc:93.49%, val_loss:1.4406, val_acc:69.23%
#  Epoch 354: iteration 106/107
# Epoch 354 --> loss:0.1192, acc:95.52%, val_loss:1.2339, val_acc:66.43%
#  Epoch 355: iteration 106/107
# Epoch 355 --> loss:0.0836, acc:96.75%, val_loss:1.2038, val_acc:74.13%
#  Epoch 356: iteration 106/107
# Epoch 356 --> loss:0.0778, acc:97.12%, val_loss:1.3232, val_acc:72.03%
#  Epoch 357: iteration 106/107
# Epoch 357 --> loss:0.1912, acc:93.08%, val_loss:1.2709, val_acc:67.13%
#  Epoch 358: iteration 106/107
# Epoch 358 --> loss:0.1006, acc:96.43%, val_loss:1.1953, val_acc:69.23%
#  Epoch 359: iteration 106/107
# Epoch 359 --> loss:0.1958, acc:93.00%, val_loss:1.3327, val_acc:64.34%
#  Epoch 360: iteration 106/107
# Epoch 360 --> loss:0.0605, acc:97.68%, val_loss:1.0813, val_acc:71.33%
#  Epoch 361: iteration 106/107
# Epoch 361 --> loss:0.0349, acc:98.84%, val_loss:1.0826, val_acc:70.63%
#  Epoch 362: iteration 106/107
# Epoch 362 --> loss:0.0298, acc:98.81%, val_loss:1.2734, val_acc:67.83%
#  Epoch 363: iteration 106/107
# Epoch 363 --> loss:0.0608, acc:97.73%, val_loss:1.0404, val_acc:76.22%
#  Epoch 364: iteration 106/107
# Epoch 364 --> loss:0.1199, acc:95.47%, val_loss:1.2026, val_acc:72.73%
#  Epoch 365: iteration 106/107
# Epoch 365 --> loss:0.0665, acc:97.50%, val_loss:1.0728, val_acc:74.83%
#  Epoch 366: iteration 106/107
# Epoch 366 --> loss:0.0694, acc:97.33%, val_loss:1.1895, val_acc:67.83%
#  Epoch 367: iteration 106/107
# Epoch 367 --> loss:0.0988, acc:96.31%, val_loss:1.0846, val_acc:72.73%
#  Epoch 368: iteration 106/107
# Epoch 368 --> loss:0.0565, acc:97.85%, val_loss:1.2240, val_acc:72.73%
#  Epoch 369: iteration 106/107
# Epoch 369 --> loss:0.0823, acc:96.95%, val_loss:1.4068, val_acc:67.13%
#  Epoch 370: iteration 106/107
# Epoch 370 --> loss:0.1335, acc:94.83%, val_loss:1.4492, val_acc:64.34%
#  Epoch 371: iteration 106/107
# Epoch 371 --> loss:0.1721, acc:93.46%, val_loss:1.2917, val_acc:68.53%
#  Epoch 372: iteration 106/107
# Epoch 372 --> loss:0.0888, acc:96.45%, val_loss:1.0555, val_acc:74.13%
#  Epoch 373: iteration 106/107
# Epoch 373 --> loss:0.0630, acc:97.18%, val_loss:1.2884, val_acc:69.23%
#  Epoch 374: iteration 106/107
# Epoch 374 --> loss:0.1385, acc:94.74%, val_loss:1.2718, val_acc:69.23%
#  Epoch 375: iteration 106/107
# Epoch 375 --> loss:0.1577, acc:93.93%, val_loss:1.4776, val_acc:62.24%
#  Epoch 376: iteration 106/107
# Epoch 376 --> loss:0.0963, acc:96.43%, val_loss:1.1286, val_acc:65.03%
#  Epoch 377: iteration 106/107
# Epoch 377 --> loss:0.0874, acc:96.98%, val_loss:1.1363, val_acc:72.03%
#  Epoch 378: iteration 106/107
# Epoch 378 --> loss:0.0268, acc:99.04%, val_loss:1.2118, val_acc:69.93%
#  Epoch 379: iteration 106/107
# Epoch 379 --> loss:0.0396, acc:98.40%, val_loss:1.1746, val_acc:75.52%
#  Epoch 380: iteration 106/107
# Epoch 380 --> loss:0.0364, acc:98.55%, val_loss:1.1947, val_acc:73.43%
#  Epoch 381: iteration 106/107
# Epoch 381 --> loss:0.0237, acc:99.04%, val_loss:1.2364, val_acc:74.83%
#  Epoch 382: iteration 106/107
# Epoch 382 --> loss:0.0855, acc:96.69%, val_loss:1.1744, val_acc:72.03%
#  Epoch 383: iteration 106/107
# Epoch 383 --> loss:0.1154, acc:95.50%, val_loss:1.8543, val_acc:62.24%
#  Epoch 384: iteration 106/107
# Epoch 384 --> loss:0.1254, acc:95.26%, val_loss:1.2440, val_acc:66.43%
#  Epoch 385: iteration 106/107
# Epoch 385 --> loss:0.1099, acc:95.73%, val_loss:1.1401, val_acc:69.93%
#  Epoch 386: iteration 106/107
# Epoch 386 --> loss:0.1178, acc:95.23%, val_loss:1.4981, val_acc:67.13%
#  Epoch 387: iteration 106/107
# Epoch 387 --> loss:0.0679, acc:97.53%, val_loss:1.3668, val_acc:68.53%
#  Epoch 388: iteration 106/107
# Epoch 388 --> loss:0.0483, acc:97.91%, val_loss:1.1772, val_acc:74.13%
#  Epoch 389: iteration 106/107
# Epoch 389 --> loss:0.0255, acc:99.13%, val_loss:1.0674, val_acc:74.83%
#  Epoch 390: iteration 106/107
# Epoch 390 --> loss:0.0121, acc:99.39%, val_loss:1.0636, val_acc:75.52%
#  Epoch 391: iteration 106/107
# Epoch 391 --> loss:0.0111, acc:99.42%, val_loss:1.2635, val_acc:73.43%
#  Epoch 392: iteration 106/107
# Epoch 392 --> loss:0.1950, acc:93.20%, val_loss:1.1948, val_acc:69.23%
#  Epoch 393: iteration 106/107
# Epoch 393 --> loss:0.0998, acc:96.40%, val_loss:1.3908, val_acc:68.53%
#  Epoch 394: iteration 106/107
# Epoch 394 --> loss:0.0487, acc:98.05%, val_loss:1.2466, val_acc:72.73%
#  Epoch 395: iteration 106/107
# Epoch 395 --> loss:0.0439, acc:98.31%, val_loss:1.2558, val_acc:68.53%
#  Epoch 396: iteration 106/107
# Epoch 396 --> loss:0.1034, acc:95.90%, val_loss:1.2622, val_acc:71.33%
#  Epoch 397: iteration 106/107
# Epoch 397 --> loss:0.0675, acc:97.47%, val_loss:1.4315, val_acc:67.83%
#  Epoch 398: iteration 106/107
# Epoch 398 --> loss:0.0934, acc:96.63%, val_loss:1.6126, val_acc:62.94%
#  Epoch 399: iteration 106/107
# Epoch 399 --> loss:0.0943, acc:96.43%, val_loss:1.6391, val_acc:62.24%
#  Epoch 400: iteration 106/107
# Epoch 400 --> loss:0.1216, acc:94.86%, val_loss:1.3433, val_acc:67.13%
#  Epoch 401: iteration 106/107
# Epoch 401 --> loss:0.1336, acc:95.06%, val_loss:1.4815, val_acc:65.03%
#  Epoch 402: iteration 106/107
# Epoch 402 --> loss:0.0917, acc:96.69%, val_loss:1.2405, val_acc:71.33%
#  Epoch 403: iteration 106/107
# Epoch 403 --> loss:0.0712, acc:97.27%, val_loss:1.1284, val_acc:74.13%
#  Epoch 404: iteration 106/107
# Epoch 404 --> loss:0.1393, acc:94.71%, val_loss:1.3698, val_acc:69.93%
#  Epoch 405: iteration 106/107
# Epoch 405 --> loss:0.1243, acc:95.03%, val_loss:1.0738, val_acc:72.03%
#  Epoch 406: iteration 106/107
# Epoch 406 --> loss:0.0823, acc:96.89%, val_loss:1.2026, val_acc:72.03%
#  Epoch 407: iteration 106/107
# Epoch 407 --> loss:0.0355, acc:98.63%, val_loss:1.1192, val_acc:71.33%
#  Epoch 408: iteration 106/107
# Epoch 408 --> loss:0.0780, acc:97.04%, val_loss:1.6396, val_acc:64.34%
#  Epoch 409: iteration 106/107
# Epoch 409 --> loss:0.1978, acc:93.03%, val_loss:1.2655, val_acc:68.53%
#  Epoch 410: iteration 106/107
# Epoch 410 --> loss:0.0766, acc:96.92%, val_loss:1.1133, val_acc:70.63%
#  Epoch 411: iteration 106/107
# Epoch 411 --> loss:0.0217, acc:99.10%, val_loss:0.9876, val_acc:73.43%
#  Epoch 412: iteration 106/107
# Epoch 412 --> loss:0.0147, acc:99.30%, val_loss:1.0934, val_acc:74.13%
#  Epoch 413: iteration 106/107
# Epoch 413 --> loss:0.0110, acc:99.45%, val_loss:1.0984, val_acc:73.43%
#  Epoch 414: iteration 106/107
# Epoch 414 --> loss:0.0108, acc:99.42%, val_loss:1.1334, val_acc:75.52%
#  Epoch 415: iteration 106/107
# Epoch 415 --> loss:0.0072, acc:99.48%, val_loss:0.9979, val_acc:75.52%
#  Epoch 416: iteration 106/107
# Epoch 416 --> loss:0.0084, acc:99.45%, val_loss:1.0894, val_acc:74.13%
#  Epoch 417: iteration 106/107
# Epoch 417 --> loss:0.0389, acc:98.17%, val_loss:1.3132, val_acc:68.53%
#  Epoch 418: iteration 106/107
# Epoch 418 --> loss:0.2046, acc:92.59%, val_loss:1.2230, val_acc:72.03%
#  Epoch 419: iteration 106/107
# Epoch 419 --> loss:0.1299, acc:95.15%, val_loss:1.3597, val_acc:69.23%
#  Epoch 420: iteration 106/107
# Epoch 420 --> loss:0.0568, acc:97.85%, val_loss:1.4318, val_acc:67.83%
#  Epoch 421: iteration 106/107
# Epoch 421 --> loss:0.0675, acc:97.27%, val_loss:2.2380, val_acc:58.04%
#  Epoch 422: iteration 106/107
# Epoch 422 --> loss:0.0951, acc:96.11%, val_loss:1.0590, val_acc:74.13%
#  Epoch 423: iteration 106/107
# Epoch 423 --> loss:0.1339, acc:94.91%, val_loss:1.1398, val_acc:69.23%
#  Epoch 424: iteration 106/107
# Epoch 424 --> loss:0.0684, acc:97.53%, val_loss:1.1473, val_acc:74.13%
#  Epoch 425: iteration 106/107
# Epoch 425 --> loss:0.1045, acc:95.61%, val_loss:1.4089, val_acc:69.93%
#  Epoch 426: iteration 106/107
# Epoch 426 --> loss:0.1952, acc:92.50%, val_loss:1.3290, val_acc:66.43%
#  Epoch 427: iteration 106/107
# Epoch 427 --> loss:0.1620, acc:93.75%, val_loss:1.1392, val_acc:71.33%
#  Epoch 428: iteration 106/107
# Epoch 428 --> loss:0.1600, acc:93.55%, val_loss:1.1484, val_acc:73.43%
#  Epoch 429: iteration 106/107
# Epoch 429 --> loss:0.0401, acc:98.52%, val_loss:1.1108, val_acc:73.43%
#  Epoch 430: iteration 106/107
# Epoch 430 --> loss:0.0389, acc:98.66%, val_loss:0.9938, val_acc:72.73%
#  Epoch 431: iteration 106/107
# Epoch 431 --> loss:0.0167, acc:99.39%, val_loss:1.0149, val_acc:75.52%
#  Epoch 432: iteration 106/107
# Epoch 432 --> loss:0.0157, acc:99.30%, val_loss:0.9624, val_acc:75.52%
#  Epoch 433: iteration 106/107
# Epoch 433 --> loss:0.0095, acc:99.45%, val_loss:0.9831, val_acc:72.73%
#  Epoch 434: iteration 106/107
# Epoch 434 --> loss:0.0065, acc:99.51%, val_loss:0.9482, val_acc:74.13%
#  Epoch 435: iteration 106/107
# Epoch 435 --> loss:0.0083, acc:99.45%, val_loss:0.8586, val_acc:74.13%
#  Epoch 436: iteration 106/107
# Epoch 436 --> loss:0.0193, acc:99.16%, val_loss:1.0165, val_acc:74.13%
#  Epoch 437: iteration 106/107
# Epoch 437 --> loss:0.0350, acc:98.55%, val_loss:1.2040, val_acc:72.03%
#  Epoch 438: iteration 106/107
# Epoch 438 --> loss:0.0595, acc:97.62%, val_loss:1.1335, val_acc:73.43%
#  Epoch 439: iteration 106/107
# Epoch 439 --> loss:0.1083, acc:95.64%, val_loss:1.6993, val_acc:64.34%
#  Epoch 440: iteration 106/107
# Epoch 440 --> loss:0.1547, acc:93.81%, val_loss:1.2746, val_acc:70.63%
#  Epoch 441: iteration 106/107
# Epoch 441 --> loss:0.1603, acc:93.58%, val_loss:1.2158, val_acc:70.63%
#  Epoch 442: iteration 106/107
# Epoch 442 --> loss:0.1355, acc:94.83%, val_loss:1.6670, val_acc:65.73%
#  Epoch 443: iteration 106/107
# Epoch 443 --> loss:0.1008, acc:96.05%, val_loss:1.4571, val_acc:63.64%
#  Epoch 444: iteration 106/107
# Epoch 444 --> loss:0.1170, acc:95.55%, val_loss:1.2622, val_acc:68.53%
#  Epoch 445: iteration 106/107
# Epoch 445 --> loss:0.0977, acc:96.37%, val_loss:1.4809, val_acc:66.43%
#  Epoch 446: iteration 106/107
# Epoch 446 --> loss:0.0808, acc:97.24%, val_loss:1.3057, val_acc:69.93%
#  Epoch 447: iteration 106/107
# Epoch 447 --> loss:0.0577, acc:97.68%, val_loss:1.3199, val_acc:66.43%
#  Epoch 448: iteration 106/107
# Epoch 448 --> loss:0.0446, acc:98.31%, val_loss:1.1445, val_acc:74.13%
#  Epoch 449: iteration 106/107
# Epoch 449 --> loss:0.0693, acc:97.24%, val_loss:1.3354, val_acc:65.73%
#  Epoch 450: iteration 106/107
# Epoch 450 --> loss:0.2146, acc:92.21%, val_loss:1.1585, val_acc:71.33%
#  Epoch 451: iteration 106/107
# Epoch 451 --> loss:0.0517, acc:98.14%, val_loss:1.0650, val_acc:74.13%
#  Epoch 452: iteration 106/107
# Epoch 452 --> loss:0.0203, acc:99.16%, val_loss:1.0092, val_acc:73.43%
#  Epoch 453: iteration 106/107
# Epoch 453 --> loss:0.0135, acc:99.33%, val_loss:1.1506, val_acc:72.03%
#  Epoch 454: iteration 106/107
# Epoch 454 --> loss:0.0103, acc:99.48%, val_loss:0.9835, val_acc:79.72%
#  Epoch 455: iteration 106/107
# Epoch 455 --> loss:0.0246, acc:98.84%, val_loss:0.9446, val_acc:74.83%
#  Epoch 456: iteration 106/107
# Epoch 456 --> loss:0.0784, acc:96.92%, val_loss:1.7810, val_acc:64.34%
#  Epoch 457: iteration 106/107
# Epoch 457 --> loss:0.2192, acc:92.33%, val_loss:1.4499, val_acc:65.73%
#  Epoch 458: iteration 106/107
# Epoch 458 --> loss:0.1197, acc:95.09%, val_loss:1.3923, val_acc:64.34%
#  Epoch 459: iteration 106/107
# Epoch 459 --> loss:0.0915, acc:96.54%, val_loss:1.4160, val_acc:70.63%
#  Epoch 460: iteration 106/107
# Epoch 460 --> loss:0.1024, acc:95.87%, val_loss:1.4124, val_acc:62.94%
#  Epoch 461: iteration 106/107
# Epoch 461 --> loss:0.0360, acc:98.66%, val_loss:1.4430, val_acc:67.13%
#  Epoch 462: iteration 106/107
# Epoch 462 --> loss:0.1311, acc:94.91%, val_loss:1.2218, val_acc:68.53%
#  Epoch 463: iteration 106/107
# Epoch 463 --> loss:0.0687, acc:97.18%, val_loss:1.5191, val_acc:66.43%
#  Epoch 464: iteration 106/107
# Epoch 464 --> loss:0.1325, acc:94.74%, val_loss:1.2265, val_acc:72.03%
#  Epoch 465: iteration 106/107
# Epoch 465 --> loss:0.1184, acc:95.61%, val_loss:1.0370, val_acc:74.83%
#  Epoch 466: iteration 106/107
# Epoch 466 --> loss:0.0306, acc:98.78%, val_loss:1.0302, val_acc:74.83%
#  Epoch 467: iteration 106/107
# Epoch 467 --> loss:0.0253, acc:98.90%, val_loss:1.1123, val_acc:73.43%
#  Epoch 468: iteration 106/107
# Epoch 468 --> loss:0.0634, acc:97.27%, val_loss:1.3504, val_acc:72.73%
#  Epoch 469: iteration 106/107
# Epoch 469 --> loss:0.1078, acc:95.73%, val_loss:1.3538, val_acc:69.93%
#  Epoch 470: iteration 106/107
# Epoch 470 --> loss:0.1972, acc:92.65%, val_loss:1.7999, val_acc:61.54%
#  Epoch 471: iteration 106/107
# Epoch 471 --> loss:0.1007, acc:95.87%, val_loss:1.2707, val_acc:70.63%
#  Epoch 472: iteration 106/107
# Epoch 472 --> loss:0.0266, acc:98.92%, val_loss:1.0964, val_acc:74.13%
#  Epoch 473: iteration 106/107
# Epoch 473 --> loss:0.0266, acc:98.92%, val_loss:1.0648, val_acc:74.83%
#  Epoch 474: iteration 106/107
# Epoch 474 --> loss:0.0353, acc:98.58%, val_loss:1.3274, val_acc:70.63%
#  Epoch 475: iteration 106/107
# Epoch 475 --> loss:0.0217, acc:98.98%, val_loss:1.2570, val_acc:69.93%
#  Epoch 476: iteration 106/107
# Epoch 476 --> loss:0.0352, acc:98.66%, val_loss:1.3809, val_acc:67.83%
#  Epoch 477: iteration 106/107
# Epoch 477 --> loss:0.0933, acc:96.66%, val_loss:1.5038, val_acc:66.43%
#  Epoch 478: iteration 106/107
# Epoch 478 --> loss:0.1346, acc:94.86%, val_loss:1.4618, val_acc:71.33%
#  Epoch 479: iteration 106/107
# Epoch 479 --> loss:0.1780, acc:93.75%, val_loss:1.1028, val_acc:72.03%
#  Epoch 480: iteration 106/107
# Epoch 480 --> loss:0.0983, acc:96.08%, val_loss:1.2693, val_acc:69.23%
#  Epoch 481: iteration 106/107
# Epoch 481 --> loss:0.0829, acc:96.77%, val_loss:1.3829, val_acc:67.13%
#  Epoch 482: iteration 106/107
# Epoch 482 --> loss:0.0524, acc:98.14%, val_loss:1.4612, val_acc:69.23%
#  Epoch 483: iteration 106/107
# Epoch 483 --> loss:0.1012, acc:96.11%, val_loss:1.1888, val_acc:68.53%
#  Epoch 484: iteration 106/107
# Epoch 484 --> loss:0.1018, acc:96.05%, val_loss:1.3639, val_acc:69.23%
#  Epoch 485: iteration 106/107
# Epoch 485 --> loss:0.0605, acc:97.44%, val_loss:1.3512, val_acc:68.53%
#  Epoch 486: iteration 106/107
# Epoch 486 --> loss:0.0459, acc:98.20%, val_loss:1.3403, val_acc:69.93%
#  Epoch 487: iteration 106/107
# Epoch 487 --> loss:0.0885, acc:96.25%, val_loss:1.0458, val_acc:74.13%
#  Epoch 488: iteration 106/107
# Epoch 488 --> loss:0.0890, acc:96.77%, val_loss:1.1422, val_acc:70.63%
#  Epoch 489: iteration 106/107
# Epoch 489 --> loss:0.2396, acc:91.92%, val_loss:1.3009, val_acc:71.33%
#  Epoch 490: iteration 106/107
# Epoch 490 --> loss:0.0668, acc:97.65%, val_loss:1.1273, val_acc:73.43%
#  Epoch 491: iteration 106/107
# Epoch 491 --> loss:0.0306, acc:98.81%, val_loss:1.0497, val_acc:72.03%
#  Epoch 492: iteration 106/107
# Epoch 492 --> loss:0.0200, acc:99.10%, val_loss:1.1673, val_acc:69.93%
#  Epoch 493: iteration 106/107
# Epoch 493 --> loss:0.0910, acc:96.57%, val_loss:1.5998, val_acc:65.03%
#  Epoch 494: iteration 106/107
# Epoch 494 --> loss:0.1671, acc:94.10%, val_loss:1.2537, val_acc:67.83%
#  Epoch 495: iteration 106/107
# Epoch 495 --> loss:0.0423, acc:98.31%, val_loss:1.3051, val_acc:72.73%
#  Epoch 496: iteration 106/107
# Epoch 496 --> loss:0.0410, acc:98.34%, val_loss:1.3512, val_acc:68.53%
#  Epoch 497: iteration 106/107
# Epoch 497 --> loss:0.1215, acc:95.15%, val_loss:1.3096, val_acc:67.83%
#  Epoch 498: iteration 106/107
# Epoch 498 --> loss:0.1115, acc:95.38%, val_loss:1.5253, val_acc:66.43%
#  Epoch 499: iteration 106/107
# Epoch 499 --> loss:0.0540, acc:97.79%, val_loss:1.2497, val_acc:66.43%

# %% [markdown]
# # Save model

# %%
SAVE_PATH = os.path.join('E:/Bhuvan/MODELS/')
os.makedirs('models',exist_ok=True)
torch.save(model.state_dict(),os.path.join(SAVE_PATH,'cnn_transf_parallel_model.pt'))
print('Model is saved to {}'.format(os.path.join(SAVE_PATH,'cnn_transf_parallel_model.pt')))
# Out:
# Model is saved to E:/Bhuvan/MODELS/cnn_transf_parallel_model.pt

# %% [markdown]
# # Load model

# %%
LOAD_PATH = os.path.join('E:/Bhuvan/MODELS/')
model = ParallelModel(len(EMOTIONS))
model.load_state_dict(torch.load(os.path.join(LOAD_PATH,'cnn_transf_parallel_model.pt')))
print('Model is loaded from {}'.format(os.path.join(LOAD_PATH,'cnn_transf_parallel_model.pt')))
# Out:
# Model is loaded from E:/Bhuvan/MODELS/cnn_transf_parallel_model.pt

# %% [markdown]
# # Test

# %%
X_test_tensor = torch.tensor(X_test,device=device).float()
Y_test_tensor = torch.tensor(Y_test,dtype=torch.long,device=device)
test_loss, test_acc, predictions = validate(X_test_tensor,Y_test_tensor)
print(f'Test loss is {test_loss:.3f}')
print(f'Test accuracy is {test_acc:.2f}%')
# Out:
# Test loss is 1.479
# Test accuracy is 70.00%

# %% [markdown]
# confusion matrix

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn

predictions = predictions.cpu().numpy()
cm = confusion_matrix(Y_test, predictions)
names = [EMOTIONS[ind] for ind in range(len(EMOTIONS))]
df_cm = pd.DataFrame(cm, index=names, columns=names)
# plt.figure(figsize=(10,7))
sn.set(font_scale=1.4) # for label size
sn.heatmap(df_cm, annot=True, annot_kws={"size": 16}) # font size
plt.show()

# %% [markdown]
# correlation between emotion intensity and corectness

# %%
correct_strong = 0
correct_normal = 0
wrong_strong = 0
wrong_normal = 0
for i in range(len(X_test)):
    intensity = data.loc[test_ind[i],'Emotion intensity']
    if Y_test[i] == predictions[i]: # correct prediction
        if  intensity == 'normal':
            correct_normal += 1
        else:
            correct_strong += 1
    else: # wrong prediction
        if intensity == 'normal':
            wrong_normal += 1
        else:
            wrong_strong += 1
array = np.array([[wrong_normal,wrong_strong],[correct_normal,correct_strong]])
df = pd.DataFrame(array,['wrong','correct'],['normal','strong'])
sn.set(font_scale=1.4) # for label size
sn.heatmap(df, annot=True, annot_kws={"size": 16}) # font size
plt.show()

# %% [markdown]
# correlation between gender and corectness

# %%
correct_male = 0
correct_female = 0
wrong_male = 0
wrong_female = 0
for i in range(len(X_test)):
    gender = data.loc[test_ind[i],'Gender']
    if Y_test[i] == predictions[i]: # correct prediction
        if  gender == 'male':
            correct_male += 1
        else:
            correct_female += 1
    else: # wrong prediction
        if gender == 'male':
            wrong_male += 1
        else:
            wrong_female += 1
array = np.array([[wrong_male,wrong_female],[correct_male,correct_female]])
df = pd.DataFrame(array,['wrong','correct'],['male','female'])
sn.set(font_scale=1.4) # for label size
sn.heatmap(df, annot=True, annot_kws={"size": 16}) # font size
plt.show()

# %% [markdown]
# # Plot loss

# %%
plt.plot(losses,'b')
plt.plot(val_losses,'r')
plt.legend(['train loss','val loss'])
plt.show()

# %%
plt.plot(acc_ep,'b')
plt.plot(vala,'r')
plt.legend(['train accuracy','val accuracy'])
plt.show()
