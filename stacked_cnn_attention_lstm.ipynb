# %% [markdown]
# # Load file names

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np
import pandas as pd
import os
import librosa
import librosa.display
import IPython
from IPython.display import Audio
from IPython.display import Image
import matplotlib.pyplot as plt

EMOTIONS = {1:'neutral', 2:'calm', 3:'happy', 4:'sad', 5:'angry', 6:'fear', 7:'disgust', 0:'surprise'} # surprise je promenjen sa 8 na 0
DATA_PATH = 'E:/Bhuvan/Dataset'
SAMPLE_RATE = 48000

data = pd.DataFrame(columns=['Emotion', 'Emotion intensity', 'Gender','Path'])
for dirname, _, filenames in os.walk(DATA_PATH):
    for filename in filenames:
        file_path = os.path.join(dirname, filename)
        identifiers = filename.split('.')[0].split('-')
        emotion = (int(identifiers[2]))
        if emotion == 8: # promeni surprise sa 8 na 0
            emotion = 0
        if int(identifiers[3]) == 1:
            emotion_intensity = 'normal' 
        else:
            emotion_intensity = 'strong'
        if int(identifiers[6])%2 == 0:
            gender = 'female'
        else:
            gender = 'male'
        
        data = data.append({"Emotion": emotion,
                            "Emotion intensity": emotion_intensity,
                            "Gender": gender,
                            "Path": file_path
                             },
                             ignore_index = True
                          )
# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
print("number of files is {}".format(len(data)))
data.head()
# Out:
# number of files is 1440
#   Emotion Emotion intensity  Gender  \
# 0       1            normal    male
# 1       1            normal  female
# 2       1            normal    male
# 3       1            normal  female
# 4       1            normal    male
#
#                                          Path
# 0  E:/Bhuvan/Dataset\03-01-01-01-01-01-01.wav
# 1  E:/Bhuvan/Dataset\03-01-01-01-01-01-02.wav
# 2  E:/Bhuvan/Dataset\03-01-01-01-01-01-03.wav
# 3  E:/Bhuvan/Dataset\03-01-01-01-01-01-04.wav
# 4  E:/Bhuvan/Dataset\03-01-01-01-01-01-05.wav

# %% [markdown]
# number of examples per emotion

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.bar(x=range(8), height=data['Emotion'].value_counts())
ax.set_xticks(ticks=range(8))
ax.set_xticklabels([EMOTIONS[i] for i in range(8)],fontsize=10)
ax.set_xlabel('Emotions')
ax.set_ylabel('Number of examples')
# Out:
# Text(0, 0.5, 'Number of examples')

# %% [markdown]
# number of examples per gender

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
counts = data['Gender'].value_counts()
ax.bar(x=[0,1], height=counts.values)
ax.set_xticks(ticks=[0,1])
ax.set_xticklabels(list(counts.index))
ax.set_xlabel('Gender')
ax.set_ylabel('Number of examples')
# Out:
# Text(0, 0.5, 'Number of examples')

# %% [markdown]
# number of examples per emotion intensity

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
counts = data['Emotion intensity'].value_counts()
ax.bar(x=[0,1], height=counts.values)
ax.set_xticks(ticks=[0,1])
ax.set_xticklabels(list(counts.index))
ax.set_xlabel('Gender')
ax.set_ylabel('Number of examples')
# Out:
# Text(0, 0.5, 'Number of examples')

# %% [markdown]
# # Load the signals

# %%
mel_spectrograms = []
signals = []
for i, file_path in enumerate(data.Path):
    audio, sample_rate = librosa.load(file_path, duration=3, offset=0.5, sr=SAMPLE_RATE)
    signal = np.zeros((int(SAMPLE_RATE*3,)))
    signal[:len(audio)] = audio
    signals.append(signal)
    print("\r Processed {}/{} files".format(i,len(data)),end='')
signals = np.stack(signals,axis=0)
# Out:
#  Processed 1439/1440 files

# %% [markdown]
# # Split the data

# %%
X = signals
train_ind,test_ind,val_ind = [],[],[]
X_train,X_val,X_test = [],[],[]
Y_train,Y_val,Y_test = [],[],[]
for emotion in range(len(EMOTIONS)):
    emotion_ind = list(data.loc[data.Emotion==emotion,'Emotion'].index)
    emotion_ind = np.random.permutation(emotion_ind)
    m = len(emotion_ind)
    ind_train = emotion_ind[:int(0.8*m)]
    ind_val = emotion_ind[int(0.8*m):int(0.9*m)]
    ind_test = emotion_ind[int(0.9*m):]
    X_train.append(X[ind_train,:])
    Y_train.append(np.array([emotion]*len(ind_train),dtype=np.int32))
    X_val.append(X[ind_val,:])
    Y_val.append(np.array([emotion]*len(ind_val),dtype=np.int32))
    X_test.append(X[ind_test,:])
    Y_test.append(np.array([emotion]*len(ind_test),dtype=np.int32))
    train_ind.append(ind_train)
    test_ind.append(ind_test)
    val_ind.append(ind_val)
X_train = np.concatenate(X_train,0)
X_val = np.concatenate(X_val,0)
X_test = np.concatenate(X_test,0)
Y_train = np.concatenate(Y_train,0)
Y_val = np.concatenate(Y_val,0)
Y_test = np.concatenate(Y_test,0)
train_ind = np.concatenate(train_ind,0)
val_ind = np.concatenate(val_ind,0)
test_ind = np.concatenate(test_ind,0)
print(f'X_train:{X_train.shape}, Y_train:{Y_train.shape}')
print(f'X_val:{X_val.shape}, Y_val:{Y_val.shape}')
print(f'X_test:{X_test.shape}, Y_test:{Y_test.shape}')
# check if all are unique
unique, count = np.unique(np.concatenate([train_ind,test_ind,val_ind],0), return_counts=True)
print("Number of unique indexes is {}, out of {}".format(sum(count==1), X.shape[0]))

del X
# Out:
# X_train:(1147, 144000), Y_train:(1147,)
# X_val:(143, 144000), Y_val:(143,)
# X_test:(150, 144000), Y_test:(150,)
# Number of unique indexes is 1440, out of 1440

# %% [markdown]
# # Augment signals by adding AWGN

# %%
def addAWGN(signal, num_bits=16, augmented_num=2, snr_low=15, snr_high=30): 
    signal_len = len(signal)
    # Generate White Gaussian noise
    noise = np.random.normal(size=(augmented_num, signal_len))
    # Normalize signal and noise
    norm_constant = 2.0**(num_bits-1)
    signal_norm = signal / norm_constant
    noise_norm = noise / norm_constant
    # Compute signal and noise power
    s_power = np.sum(signal_norm ** 2) / signal_len
    n_power = np.sum(noise_norm ** 2, axis=1) / signal_len
    # Random SNR: Uniform [15, 30] in dB
    target_snr = np.random.randint(snr_low, snr_high)
    # Compute K (covariance matrix) for each noise 
    K = np.sqrt((s_power / n_power) * 10 ** (- target_snr / 10))
    K = np.ones((signal_len, augmented_num)) * K  
    # Generate noisy signal
    return signal + K.T * noise

# %%
aug_signals = []
aug_labels = []
for i in range(X_train.shape[0]):
    signal = X_train[i,:]
    augmented_signals = addAWGN(signal)
    for j in range(augmented_signals.shape[0]):
        aug_labels.append(data.loc[i,"Emotion"])
        aug_signals.append(augmented_signals[j,:])
        data = data.append(data.iloc[i], ignore_index=True)
    print("\r Processed {}/{} files".format(i,X_train.shape[0]),end='')
aug_signals = np.stack(aug_signals,axis=0)
X_train = np.concatenate([X_train,aug_signals],axis=0)
aug_labels = np.stack(aug_labels,axis=0)
Y_train = np.concatenate([Y_train,aug_labels])
print('')
print(f'X_train:{X_train.shape}, Y_train:{Y_train.shape}')
# Out:
#  Processed 1146/1147 files
# X_train:(3441, 144000), Y_train:(3441,)

# %% [markdown]
# # Calculate mel spectrograms

# %%
def getMELspectrogram(audio, sample_rate):
    mel_spec = librosa.feature.melspectrogram(y=audio,
                                              sr=sample_rate,
                                              n_fft=1024,
                                              win_length = 512,
                                              window='hamming',
                                              hop_length = 256,
                                              n_mels=128,
                                              fmax=sample_rate/2
                                             )
    mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)
    return mel_spec_db

# test function
audio, sample_rate = librosa.load(data.loc[0,'Path'], duration=3, offset=0.5,sr=SAMPLE_RATE)
signal = np.zeros((int(SAMPLE_RATE*3,)))
signal[:len(audio)] = audio
mel_spectrogram = getMELspectrogram(signal, SAMPLE_RATE)
librosa.display.specshow(mel_spectrogram, y_axis='mel', x_axis='time')
print('MEL spectrogram shape: ',mel_spectrogram.shape)
# Out:
# MEL spectrogram shape:  (128, 563)

# %%
mel_train = []
print("Calculatin mel spectrograms for train set")
for i in range(X_train.shape[0]):
    mel_spectrogram = getMELspectrogram(X_train[i,:], sample_rate=SAMPLE_RATE)
    mel_train.append(mel_spectrogram)
    print("\r Processed {}/{} files".format(i,X_train.shape[0]),end='')
print('')
del X_train

mel_val = []
print("Calculatin mel spectrograms for val set")
for i in range(X_val.shape[0]):
    mel_spectrogram = getMELspectrogram(X_val[i,:], sample_rate=SAMPLE_RATE)
    mel_val.append(mel_spectrogram)
    print("\r Processed {}/{} files".format(i,X_val.shape[0]),end='')
print('')
del X_val

mel_test = []
print("Calculatin mel spectrograms for test set")
for i in range(X_test.shape[0]):
    mel_spectrogram = getMELspectrogram(X_test[i,:], sample_rate=SAMPLE_RATE)
    mel_test.append(mel_spectrogram)
    print("\r Processed {}/{} files".format(i,X_test.shape[0]),end='')
print('')
del X_test
# Out:
# Calculatin mel spectrograms for train set
#  Processed 3440/3441 files
# Calculatin mel spectrograms for val set
#  Processed 142/143 files
# Calculatin mel spectrograms for test set
#  Processed 149/150 files

# %% [markdown]
# # Split into chunks

# %%
def splitIntoChunks(mel_spec,win_size,stride):
    t = mel_spec.shape[1]
    num_of_chunks = int(t/stride)
    chunks = []
    for i in range(num_of_chunks):
        chunk = mel_spec[:,i*stride:i*stride+win_size]
        if chunk.shape[1] == win_size:
            chunks.append(chunk)
    return np.stack(chunks,axis=0)

# %%
# get chunks
# train set
mel_train_chunked = []
for mel_spec in mel_train:
    chunks = splitIntoChunks(mel_spec, win_size=128,stride=64)
    mel_train_chunked.append(chunks)
print("Number of chunks is {}".format(chunks.shape[0]))
# val set
mel_val_chunked = []
for mel_spec in mel_val:
    chunks = splitIntoChunks(mel_spec, win_size=128,stride=64)
    mel_val_chunked.append(chunks)
print("Number of chunks is {}".format(chunks.shape[0]))
# test set
mel_test_chunked = []
for mel_spec in mel_test:
    chunks = splitIntoChunks(mel_spec, win_size=128,stride=64)
    mel_test_chunked.append(chunks)
print("Number of chunks is {}".format(chunks.shape[0]))
# Out:
# Number of chunks is 7
# Number of chunks is 7
# Number of chunks is 7

# %% [markdown]
# # Create the model

# %%
import torch
import torch.nn as nn
# BATCH FIRST TimeDistributed layer
class TimeDistributed(nn.Module):
    def __init__(self, module):
        super(TimeDistributed, self).__init__()
        self.module = module

    def forward(self, x):

        if len(x.size()) <= 2:
            return self.module(x)
        # squash samples and timesteps into a single axis
        elif len(x.size()) == 3: # (samples, timesteps, inp1)
            x_reshape = x.contiguous().view(-1, x.size(2))  # (samples * timesteps, inp1)
        elif len(x.size()) == 4: # (samples,timesteps,inp1,inp2)
            x_reshape = x.contiguous().view(-1, x.size(2), x.size(3)) # (samples*timesteps,inp1,inp2)
        else: # (samples,timesteps,inp1,inp2,inp3)
            x_reshape = x.contiguous().view(-1, x.size(2), x.size(3),x.size(4)) # (samples*timesteps,inp1,inp2,inp3)
            
        y = self.module(x_reshape)
        
        # we have to reshape Y
        if len(x.size()) == 3:
            y = y.contiguous().view(x.size(0), -1, y.size(1))  # (samples, timesteps, out1)
        elif len(x.size()) == 4:
            y = y.contiguous().view(x.size(0), -1, y.size(1), y.size(2)) # (samples, timesteps, out1,out2)
        else:
            y = y.contiguous().view(x.size(0), -1, y.size(1), y.size(2),y.size(3)) # (samples, timesteps, out1,out2, out3)
        return y

# %%
class HybridModel(nn.Module):
    def __init__(self,num_emotions):
        super().__init__()
        # conv block
        self.conv2Dblock = nn.Sequential(
            # 1. conv block
            TimeDistributed(nn.Conv2d(in_channels=1,
                                   out_channels=16,
                                   kernel_size=3,
                                   stride=1,
                                   padding=1
                                  )),
            TimeDistributed(nn.BatchNorm2d(16)),
            TimeDistributed(nn.ReLU()),
            TimeDistributed(nn.MaxPool2d(kernel_size=2, stride=2)),
            TimeDistributed(nn.Dropout(p=0.3)),
            # 2. conv block
            TimeDistributed(nn.Conv2d(in_channels=16,
                                   out_channels=32,
                                   kernel_size=3,
                                   stride=1,
                                   padding=1
                                  )),
            TimeDistributed(nn.BatchNorm2d(32)),
            TimeDistributed(nn.ReLU()),
            TimeDistributed(nn.MaxPool2d(kernel_size=4, stride=4)),
            TimeDistributed(nn.Dropout(p=0.3)),
            # 3. conv block
            TimeDistributed(nn.Conv2d(in_channels=32,
                                   out_channels=64,
                                   kernel_size=3,
                                   stride=1,
                                   padding=1
                                  )),
            TimeDistributed(nn.BatchNorm2d(64)),
            TimeDistributed(nn.ReLU()),
            TimeDistributed(nn.MaxPool2d(kernel_size=4, stride=4)),
            TimeDistributed(nn.Dropout(p=0.3))
        )
        # LSTM block
        hidden_size = 64
        self.lstm = nn.LSTM(input_size=1024,hidden_size=hidden_size,bidirectional=True, batch_first=True)
        self.dropout_lstm = nn.Dropout(p=0.4)
        self.attention_linear = nn.Linear(2*hidden_size,1) # 2*hidden_size for the 2 outputs of bidir LSTM
        # Linear softmax layer
        self.out_linear = nn.Linear(2*hidden_size,num_emotions)
    def forward(self,x):
        conv_embedding = self.conv2Dblock(x)
        conv_embedding = torch.flatten(conv_embedding, start_dim=2) # do not flatten batch dimension and time
        lstm_embedding, (h,c) = self.lstm(conv_embedding)
        lstm_embedding = self.dropout_lstm(lstm_embedding)
        # lstm_embedding (batch, time, hidden_size*2)
        batch_size,T,_ = lstm_embedding.shape 
        attention_weights = [None]*T
        for t in range(T):
            embedding = lstm_embedding[:,t,:]
            attention_weights[t] = self.attention_linear(embedding)
        attention_weights_norm = nn.functional.softmax(torch.stack(attention_weights,-1),dim=-1)
        attention = torch.bmm(attention_weights_norm,lstm_embedding) # (Bx1xT)*(B,T,hidden_size*2)=(B,1,2*hidden_size)
        attention = torch.squeeze(attention, 1)
        output_logits = self.out_linear(attention)
        output_softmax = nn.functional.softmax(output_logits,dim=1)
        return output_logits, output_softmax, attention_weights_norm

# %%
def loss_fnc(predictions, targets):
    return nn.CrossEntropyLoss()(input=predictions,target=targets)

# %% [markdown]
# # TRAINING

# %%
def make_train_step(model, loss_fnc, optimizer):
    def train_step(X,Y):
        # set model to train mode
        model.train()
        # forward pass
        output_logits, output_softmax, attention_weights_norm = model(X)
        predictions = torch.argmax(output_softmax,dim=1)
        accuracy = torch.sum(Y==predictions)/float(len(Y))
        # compute loss
        loss = loss_fnc(output_logits, Y)
        # compute gradients
        loss.backward()
        # update parameters and zero gradients
        optimizer.step()
        optimizer.zero_grad()
        return loss.item(), accuracy*100
    return train_step

# %%
def make_validate_fnc(model,loss_fnc):
    def validate(X,Y):
        with torch.no_grad():
            model.eval()
            output_logits, output_softmax, attention_weights_norm = model(X)
            predictions = torch.argmax(output_softmax,dim=1)
            accuracy = torch.sum(Y==predictions)/float(len(Y))
            loss = loss_fnc(output_logits,Y)
        return loss.item(), accuracy*100, predictions
    return validate

# %% [markdown]
# stack data

# %%
X_train = np.stack(mel_train_chunked,axis=0)
X_train = np.expand_dims(X_train,2)
print('Shape of X_train: ',X_train.shape)
X_val = np.stack(mel_val_chunked,axis=0)
X_val = np.expand_dims(X_val,2)
print('Shape of X_val: ',X_val.shape)
X_test = np.stack(mel_test_chunked,axis=0)
X_test = np.expand_dims(X_test,2)
print('Shape of X_test: ',X_test.shape)

del mel_train_chunked
del mel_train
del mel_val_chunked
del mel_val
del mel_test_chunked
del mel_test
# Out:
# Shape of X_train:  (3441, 7, 1, 128, 128)
# Shape of X_val:  (143, 7, 1, 128, 128)
# Shape of X_test:  (150, 7, 1, 128, 128)

# %% [markdown]
# scale data

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

b,t,c,h,w = X_train.shape
X_train = np.reshape(X_train, newshape=(b,-1))
X_train = scaler.fit_transform(X_train)
X_train = np.reshape(X_train, newshape=(b,t,c,h,w))

b,t,c,h,w = X_test.shape
X_test = np.reshape(X_test, newshape=(b,-1))
X_test = scaler.transform(X_test)
X_test = np.reshape(X_test, newshape=(b,t,c,h,w))

b,t,c,h,w = X_val.shape
X_val = np.reshape(X_val, newshape=(b,-1))
X_val = scaler.transform(X_val)
X_val = np.reshape(X_val, newshape=(b,t,c,h,w))

# %% [markdown]
# train the model

# %%
EPOCHS=500
DATASET_SIZE = X_train.shape[0]
BATCH_SIZE = 32
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('Selected device is {}'.format(device))
model = HybridModel(num_emotions=len(EMOTIONS)).to(device)
print('Number of trainable params: ',sum(p.numel() for p in model.parameters()))
OPTIMIZER = torch.optim.SGD(model.parameters(),lr=0.01, weight_decay=1e-3, momentum=0.8)

train_step = make_train_step(model, loss_fnc, optimizer=OPTIMIZER)
validate = make_validate_fnc(model,loss_fnc)
losses=[]
val_losses = []
acc_ep = []
vala = []
for epoch in range(EPOCHS):
    # schuffle data
    ind = np.random.permutation(DATASET_SIZE)
    X_train = X_train[ind,:,:,:,:]
    Y_train = Y_train[ind]
    epoch_acc = 0
    epoch_loss = 0
    iters = int(DATASET_SIZE / BATCH_SIZE)
    for i in range(iters):
        batch_start = i * BATCH_SIZE
        batch_end = min(batch_start + BATCH_SIZE, DATASET_SIZE)
        actual_batch_size = batch_end-batch_start
        X = X_train[batch_start:batch_end,:,:,:,:]
        Y = Y_train[batch_start:batch_end]
        X_tensor = torch.tensor(X,device=device).float()
        Y_tensor = torch.tensor(Y, dtype=torch.long,device=device)
        loss, acc = train_step(X_tensor,Y_tensor)
        epoch_acc += acc*actual_batch_size/DATASET_SIZE
        epoch_loss += loss*actual_batch_size/DATASET_SIZE
        print(f"\r Epoch {epoch}: iteration {i}/{iters}",end='')
    X_val_tensor = torch.tensor(X_val,device=device).float()
    Y_val_tensor = torch.tensor(Y_val,dtype=torch.long,device=device)
    val_loss, val_acc, _ = validate(X_val_tensor,Y_val_tensor)
    losses.append(epoch_loss)
    val_losses.append(val_loss)
    acc_ep.append(epoch_acc)
    vala.append(val_acc)
    print('')
    print(f"Epoch {epoch} --> loss:{epoch_loss:.4f}, acc:{epoch_acc:.2f}%, val_loss:{val_loss:.4f}, val_acc:{val_acc:.2f}%")
# Out:
# Selected device is cuda
# Number of trainable params:  582761
#  Epoch 0: iteration 106/107
# Epoch 0 --> loss:1.9954, acc:15.49%, val_loss:2.0928, val_acc:11.19%
#  Epoch 1: iteration 106/107
# Epoch 1 --> loss:1.9477, acc:18.37%, val_loss:2.0781, val_acc:17.48%
#  Epoch 2: iteration 106/107
# Epoch 2 --> loss:1.9111, acc:21.85%, val_loss:2.1620, val_acc:16.78%
#  Epoch 3: iteration 106/107
# Epoch 3 --> loss:1.8773, acc:23.74%, val_loss:2.2100, val_acc:16.08%
#  Epoch 4: iteration 106/107
# Epoch 4 --> loss:1.8437, acc:25.34%, val_loss:2.2311, val_acc:16.08%
#  Epoch 5: iteration 106/107
# Epoch 5 --> loss:1.8314, acc:26.13%, val_loss:2.2875, val_acc:16.78%
#  Epoch 6: iteration 106/107
# Epoch 6 --> loss:1.7989, acc:27.78%, val_loss:2.0637, val_acc:24.48%
#  Epoch 7: iteration 106/107
# Epoch 7 --> loss:1.7756, acc:28.07%, val_loss:2.0942, val_acc:20.98%
#  Epoch 8: iteration 106/107
# Epoch 8 --> loss:1.7634, acc:28.80%, val_loss:2.0077, val_acc:27.27%
#  Epoch 9: iteration 106/107
# Epoch 9 --> loss:1.7401, acc:29.76%, val_loss:1.9323, val_acc:24.48%
#  Epoch 10: iteration 106/107
# Epoch 10 --> loss:1.7300, acc:30.98%, val_loss:1.9535, val_acc:25.17%
#  Epoch 11: iteration 106/107
# Epoch 11 --> loss:1.7101, acc:31.79%, val_loss:1.8995, val_acc:30.77%
#  Epoch 12: iteration 106/107
# Epoch 12 --> loss:1.6997, acc:32.49%, val_loss:1.8068, val_acc:33.57%
#  Epoch 13: iteration 106/107
# Epoch 13 --> loss:1.6775, acc:33.54%, val_loss:1.9249, val_acc:28.67%
#  Epoch 14: iteration 106/107
# Epoch 14 --> loss:1.6639, acc:33.48%, val_loss:1.8147, val_acc:29.37%
#  Epoch 15: iteration 106/107
# Epoch 15 --> loss:1.6430, acc:34.64%, val_loss:1.7203, val_acc:39.16%
#  Epoch 16: iteration 106/107
# Epoch 16 --> loss:1.6305, acc:36.36%, val_loss:1.6377, val_acc:41.26%
#  Epoch 17: iteration 106/107
# Epoch 17 --> loss:1.6094, acc:36.27%, val_loss:1.6148, val_acc:43.36%
#  Epoch 18: iteration 106/107
# Epoch 18 --> loss:1.6098, acc:36.76%, val_loss:1.6645, val_acc:42.66%
#  Epoch 19: iteration 106/107
# Epoch 19 --> loss:1.5898, acc:37.61%, val_loss:1.5508, val_acc:46.15%
#  Epoch 20: iteration 106/107
# Epoch 20 --> loss:1.5598, acc:37.95%, val_loss:1.6060, val_acc:43.36%
#  Epoch 21: iteration 106/107
# Epoch 21 --> loss:1.5577, acc:38.42%, val_loss:1.5672, val_acc:42.66%
#  Epoch 22: iteration 106/107
# Epoch 22 --> loss:1.5339, acc:40.45%, val_loss:1.5034, val_acc:46.85%
#  Epoch 23: iteration 106/107
# Epoch 23 --> loss:1.5253, acc:41.21%, val_loss:1.5489, val_acc:44.76%
#  Epoch 24: iteration 106/107
# Epoch 24 --> loss:1.5028, acc:41.06%, val_loss:1.4588, val_acc:43.36%
#  Epoch 25: iteration 106/107
# Epoch 25 --> loss:1.4723, acc:41.67%, val_loss:1.4481, val_acc:48.25%
#  Epoch 26: iteration 106/107
# Epoch 26 --> loss:1.4667, acc:42.89%, val_loss:1.4341, val_acc:50.35%
#  Epoch 27: iteration 106/107
# Epoch 27 --> loss:1.4393, acc:44.55%, val_loss:1.4870, val_acc:41.96%
#  Epoch 28: iteration 106/107
# Epoch 28 --> loss:1.4467, acc:44.35%, val_loss:1.4121, val_acc:51.75%
#  Epoch 29: iteration 106/107
# Epoch 29 --> loss:1.4089, acc:45.92%, val_loss:1.3391, val_acc:52.45%
#  Epoch 30: iteration 106/107
# Epoch 30 --> loss:1.3935, acc:45.71%, val_loss:1.3622, val_acc:52.45%
#  Epoch 31: iteration 106/107
# Epoch 31 --> loss:1.4038, acc:45.54%, val_loss:1.3347, val_acc:48.95%
#  Epoch 32: iteration 106/107
# Epoch 32 --> loss:1.3725, acc:46.96%, val_loss:1.3520, val_acc:52.45%
#  Epoch 33: iteration 106/107
# Epoch 33 --> loss:1.3600, acc:47.22%, val_loss:1.3623, val_acc:47.55%
#  Epoch 34: iteration 106/107
# Epoch 34 --> loss:1.3369, acc:48.74%, val_loss:1.3331, val_acc:55.24%
#  Epoch 35: iteration 106/107
# Epoch 35 --> loss:1.3176, acc:48.94%, val_loss:1.2881, val_acc:55.24%
#  Epoch 36: iteration 106/107
# Epoch 36 --> loss:1.3235, acc:47.78%, val_loss:1.3244, val_acc:51.75%
#  Epoch 37: iteration 106/107
# Epoch 37 --> loss:1.2890, acc:50.51%, val_loss:1.3258, val_acc:54.55%
#  Epoch 38: iteration 106/107
# Epoch 38 --> loss:1.2746, acc:51.18%, val_loss:1.3845, val_acc:45.45%
#  Epoch 39: iteration 106/107
# Epoch 39 --> loss:1.2614, acc:51.55%, val_loss:1.3269, val_acc:52.45%
#  Epoch 40: iteration 106/107
# Epoch 40 --> loss:1.2312, acc:53.10%, val_loss:1.3087, val_acc:50.35%
#  Epoch 41: iteration 106/107
# Epoch 41 --> loss:1.2316, acc:52.78%, val_loss:1.2742, val_acc:50.35%
#  Epoch 42: iteration 106/107
# Epoch 42 --> loss:1.2087, acc:53.62%, val_loss:1.3133, val_acc:50.35%
#  Epoch 43: iteration 106/107
# Epoch 43 --> loss:1.1785, acc:55.30%, val_loss:1.2546, val_acc:53.15%
#  Epoch 44: iteration 106/107
# Epoch 44 --> loss:1.1666, acc:55.39%, val_loss:1.2677, val_acc:53.85%
#  Epoch 45: iteration 106/107
# Epoch 45 --> loss:1.1615, acc:55.77%, val_loss:1.2591, val_acc:53.85%
#  Epoch 46: iteration 106/107
# Epoch 46 --> loss:1.1299, acc:57.63%, val_loss:1.2458, val_acc:57.34%
#  Epoch 47: iteration 106/107
# Epoch 47 --> loss:1.1142, acc:57.11%, val_loss:1.2304, val_acc:53.85%
#  Epoch 48: iteration 106/107
# Epoch 48 --> loss:1.0959, acc:57.83%, val_loss:1.2906, val_acc:51.75%
#  Epoch 49: iteration 106/107
# Epoch 49 --> loss:1.0735, acc:60.19%, val_loss:1.2288, val_acc:57.34%
#  Epoch 50: iteration 106/107
# Epoch 50 --> loss:1.0721, acc:59.49%, val_loss:1.2091, val_acc:53.85%
#  Epoch 51: iteration 106/107
# Epoch 51 --> loss:1.0530, acc:59.43%, val_loss:1.3078, val_acc:51.75%
#  Epoch 52: iteration 106/107
# Epoch 52 --> loss:1.0196, acc:61.64%, val_loss:1.2425, val_acc:58.74%
#  Epoch 53: iteration 106/107
# Epoch 53 --> loss:0.9978, acc:62.34%, val_loss:1.2634, val_acc:55.24%
#  Epoch 54: iteration 106/107
# Epoch 54 --> loss:0.9898, acc:63.35%, val_loss:1.2503, val_acc:55.24%
#  Epoch 55: iteration 106/107
# Epoch 55 --> loss:0.9703, acc:63.12%, val_loss:1.3633, val_acc:48.95%
#  Epoch 56: iteration 106/107
# Epoch 56 --> loss:0.9434, acc:64.43%, val_loss:1.2146, val_acc:55.24%
#  Epoch 57: iteration 106/107
# Epoch 57 --> loss:0.9296, acc:65.04%, val_loss:1.2420, val_acc:50.35%
#  Epoch 58: iteration 106/107
# Epoch 58 --> loss:0.9294, acc:64.92%, val_loss:1.2312, val_acc:55.24%
#  Epoch 59: iteration 106/107
# Epoch 59 --> loss:0.9041, acc:65.27%, val_loss:1.4627, val_acc:49.65%
#  Epoch 60: iteration 106/107
# Epoch 60 --> loss:0.8690, acc:68.18%, val_loss:1.2351, val_acc:56.64%
#  Epoch 61: iteration 106/107
# Epoch 61 --> loss:0.8638, acc:67.86%, val_loss:1.2223, val_acc:55.24%
#  Epoch 62: iteration 106/107
# Epoch 62 --> loss:0.8510, acc:68.44%, val_loss:1.1370, val_acc:55.94%
#  Epoch 63: iteration 106/107
# Epoch 63 --> loss:0.8291, acc:67.95%, val_loss:1.2050, val_acc:57.34%
#  Epoch 64: iteration 106/107
# Epoch 64 --> loss:0.8001, acc:69.83%, val_loss:1.1173, val_acc:58.74%
#  Epoch 65: iteration 106/107
# Epoch 65 --> loss:0.8096, acc:69.54%, val_loss:1.2022, val_acc:54.55%
#  Epoch 66: iteration 106/107
# Epoch 66 --> loss:0.7949, acc:69.75%, val_loss:1.2146, val_acc:55.24%
#  Epoch 67: iteration 106/107
# Epoch 67 --> loss:0.7674, acc:70.47%, val_loss:1.1654, val_acc:53.85%
#  Epoch 68: iteration 106/107
# Epoch 68 --> loss:0.7381, acc:72.51%, val_loss:1.2373, val_acc:52.45%
#  Epoch 69: iteration 106/107
# Epoch 69 --> loss:0.7335, acc:72.54%, val_loss:1.2255, val_acc:55.94%
#  Epoch 70: iteration 106/107
# Epoch 70 --> loss:0.7127, acc:72.89%, val_loss:1.1693, val_acc:54.55%
#  Epoch 71: iteration 106/107
# Epoch 71 --> loss:0.6985, acc:74.14%, val_loss:1.2872, val_acc:53.15%
#  Epoch 72: iteration 106/107
# Epoch 72 --> loss:0.6918, acc:74.40%, val_loss:1.1766, val_acc:58.04%
#  Epoch 73: iteration 106/107
# Epoch 73 --> loss:0.6841, acc:74.48%, val_loss:1.1357, val_acc:58.04%
#  Epoch 74: iteration 106/107
# Epoch 74 --> loss:0.6592, acc:75.33%, val_loss:1.1501, val_acc:58.04%
#  Epoch 75: iteration 106/107
# Epoch 75 --> loss:0.6266, acc:77.19%, val_loss:1.0986, val_acc:59.44%
#  Epoch 76: iteration 106/107
# Epoch 76 --> loss:0.6258, acc:77.27%, val_loss:1.1300, val_acc:58.04%
#  Epoch 77: iteration 106/107
# Epoch 77 --> loss:0.6205, acc:77.13%, val_loss:1.2190, val_acc:54.55%
#  Epoch 78: iteration 106/107
# Epoch 78 --> loss:0.6103, acc:78.20%, val_loss:1.1779, val_acc:58.74%
#  Epoch 79: iteration 106/107
# Epoch 79 --> loss:0.5950, acc:77.91%, val_loss:1.1597, val_acc:57.34%
#  Epoch 80: iteration 106/107
# Epoch 80 --> loss:0.5853, acc:78.58%, val_loss:1.2194, val_acc:55.24%
#  Epoch 81: iteration 106/107
# Epoch 81 --> loss:0.5773, acc:79.48%, val_loss:1.1047, val_acc:54.55%
#  Epoch 82: iteration 106/107
# Epoch 82 --> loss:0.5679, acc:80.03%, val_loss:1.2798, val_acc:55.24%
#  Epoch 83: iteration 106/107
# Epoch 83 --> loss:0.5443, acc:79.72%, val_loss:1.1585, val_acc:59.44%
#  Epoch 84: iteration 106/107
# Epoch 84 --> loss:0.5262, acc:81.08%, val_loss:1.1260, val_acc:55.94%
#  Epoch 85: iteration 106/107
# Epoch 85 --> loss:0.5310, acc:80.85%, val_loss:1.1046, val_acc:59.44%
#  Epoch 86: iteration 106/107
# Epoch 86 --> loss:0.5039, acc:82.19%, val_loss:1.2490, val_acc:59.44%
#  Epoch 87: iteration 106/107
# Epoch 87 --> loss:0.5180, acc:81.40%, val_loss:1.2428, val_acc:60.14%
#  Epoch 88: iteration 106/107
# Epoch 88 --> loss:0.4898, acc:81.92%, val_loss:1.1933, val_acc:58.74%
#  Epoch 89: iteration 106/107
# Epoch 89 --> loss:0.4776, acc:83.64%, val_loss:1.1244, val_acc:58.04%
#  Epoch 90: iteration 106/107
# Epoch 90 --> loss:0.4622, acc:83.38%, val_loss:1.0406, val_acc:60.84%
#  Epoch 91: iteration 106/107
# Epoch 91 --> loss:0.4584, acc:84.22%, val_loss:1.1342, val_acc:63.64%
#  Epoch 92: iteration 106/107
# Epoch 92 --> loss:0.4542, acc:83.00%, val_loss:1.0995, val_acc:61.54%
#  Epoch 93: iteration 106/107
# Epoch 93 --> loss:0.4412, acc:84.45%, val_loss:1.1841, val_acc:59.44%
#  Epoch 94: iteration 106/107
# Epoch 94 --> loss:0.4349, acc:84.74%, val_loss:1.0973, val_acc:58.74%
#  Epoch 95: iteration 106/107
# Epoch 95 --> loss:0.4234, acc:85.61%, val_loss:1.1580, val_acc:59.44%
#  Epoch 96: iteration 106/107
# Epoch 96 --> loss:0.4185, acc:85.03%, val_loss:1.0780, val_acc:59.44%
#  Epoch 97: iteration 106/107
# Epoch 97 --> loss:0.3852, acc:86.89%, val_loss:1.2356, val_acc:59.44%
#  Epoch 98: iteration 106/107
# Epoch 98 --> loss:0.3828, acc:86.54%, val_loss:1.2915, val_acc:61.54%
#  Epoch 99: iteration 106/107
# Epoch 99 --> loss:0.3764, acc:86.43%, val_loss:1.1291, val_acc:60.14%
#  Epoch 100: iteration 106/107
# Epoch 100 --> loss:0.3866, acc:85.99%, val_loss:1.2455, val_acc:53.15%
#  Epoch 101: iteration 106/107
# Epoch 101 --> loss:0.3664, acc:87.07%, val_loss:1.1497, val_acc:53.15%
#  Epoch 102: iteration 106/107
# Epoch 102 --> loss:0.3716, acc:86.78%, val_loss:1.2599, val_acc:62.94%
#  Epoch 103: iteration 106/107
# Epoch 103 --> loss:0.3552, acc:87.42%, val_loss:1.1022, val_acc:63.64%
#  Epoch 104: iteration 106/107
# Epoch 104 --> loss:0.3497, acc:87.68%, val_loss:1.1766, val_acc:62.24%
#  Epoch 105: iteration 106/107
# Epoch 105 --> loss:0.3584, acc:87.85%, val_loss:1.1156, val_acc:59.44%
#  Epoch 106: iteration 106/107
# Epoch 106 --> loss:0.3263, acc:88.67%, val_loss:1.2344, val_acc:60.84%
#  Epoch 107: iteration 106/107
# Epoch 107 --> loss:0.3180, acc:89.25%, val_loss:1.0834, val_acc:60.84%
#  Epoch 108: iteration 106/107
# Epoch 108 --> loss:0.3281, acc:88.87%, val_loss:1.3674, val_acc:54.55%
#  Epoch 109: iteration 106/107
# Epoch 109 --> loss:0.3249, acc:88.99%, val_loss:1.1724, val_acc:60.14%
#  Epoch 110: iteration 106/107
# Epoch 110 --> loss:0.3167, acc:88.87%, val_loss:1.2433, val_acc:59.44%
#  Epoch 111: iteration 106/107
# Epoch 111 --> loss:0.3143, acc:88.93%, val_loss:1.3700, val_acc:61.54%
#  Epoch 112: iteration 106/107
# Epoch 112 --> loss:0.3057, acc:89.22%, val_loss:1.1598, val_acc:62.94%
#  Epoch 113: iteration 106/107
# Epoch 113 --> loss:0.3049, acc:89.54%, val_loss:1.1116, val_acc:65.03%
#  Epoch 114: iteration 106/107
# Epoch 114 --> loss:0.2757, acc:91.08%, val_loss:1.1440, val_acc:62.94%
#  Epoch 115: iteration 106/107
# Epoch 115 --> loss:0.2900, acc:90.29%, val_loss:1.2987, val_acc:59.44%
#  Epoch 116: iteration 106/107
# Epoch 116 --> loss:0.2761, acc:90.87%, val_loss:1.2132, val_acc:58.74%
#  Epoch 117: iteration 106/107
# Epoch 117 --> loss:0.2849, acc:89.80%, val_loss:1.1578, val_acc:60.84%
#  Epoch 118: iteration 106/107
# Epoch 118 --> loss:0.2608, acc:91.43%, val_loss:1.3218, val_acc:58.74%
#  Epoch 119: iteration 106/107
# Epoch 119 --> loss:0.2638, acc:91.19%, val_loss:1.2771, val_acc:58.74%
#  Epoch 120: iteration 106/107
# Epoch 120 --> loss:0.2579, acc:91.63%, val_loss:1.1776, val_acc:60.84%
#  Epoch 121: iteration 106/107
# Epoch 121 --> loss:0.2668, acc:91.17%, val_loss:1.2129, val_acc:65.03%
#  Epoch 122: iteration 106/107
# Epoch 122 --> loss:0.2573, acc:91.57%, val_loss:1.1977, val_acc:61.54%
#  Epoch 123: iteration 106/107
# Epoch 123 --> loss:0.2620, acc:91.28%, val_loss:1.3788, val_acc:58.74%
#  Epoch 124: iteration 106/107
# Epoch 124 --> loss:0.2354, acc:92.73%, val_loss:1.1632, val_acc:62.94%
#  Epoch 125: iteration 106/107
# Epoch 125 --> loss:0.2569, acc:91.25%, val_loss:1.2270, val_acc:65.03%
#  Epoch 126: iteration 106/107
# Epoch 126 --> loss:0.2492, acc:91.78%, val_loss:1.1982, val_acc:65.73%
#  Epoch 127: iteration 106/107
# Epoch 127 --> loss:0.2260, acc:92.76%, val_loss:1.1146, val_acc:65.03%
#  Epoch 128: iteration 106/107
# Epoch 128 --> loss:0.2241, acc:92.65%, val_loss:1.2964, val_acc:59.44%
#  Epoch 129: iteration 106/107
# Epoch 129 --> loss:0.2231, acc:92.59%, val_loss:1.2143, val_acc:60.84%
#  Epoch 130: iteration 106/107
# Epoch 130 --> loss:0.2379, acc:92.21%, val_loss:1.2423, val_acc:61.54%
#  Epoch 131: iteration 106/107
# Epoch 131 --> loss:0.2141, acc:92.94%, val_loss:1.2273, val_acc:60.14%
#  Epoch 132: iteration 106/107
# Epoch 132 --> loss:0.2140, acc:92.79%, val_loss:1.1480, val_acc:60.14%
#  Epoch 133: iteration 106/107
# Epoch 133 --> loss:0.2207, acc:92.56%, val_loss:1.1090, val_acc:65.03%
#  Epoch 134: iteration 106/107
# Epoch 134 --> loss:0.2063, acc:93.29%, val_loss:1.2087, val_acc:61.54%
#  Epoch 135: iteration 106/107
# Epoch 135 --> loss:0.1967, acc:93.75%, val_loss:1.2496, val_acc:61.54%
#  Epoch 136: iteration 106/107
# Epoch 136 --> loss:0.1796, acc:94.68%, val_loss:1.0671, val_acc:60.84%
#  Epoch 137: iteration 106/107
# Epoch 137 --> loss:0.1878, acc:94.25%, val_loss:1.1276, val_acc:63.64%
#  Epoch 138: iteration 106/107
# Epoch 138 --> loss:0.2002, acc:93.78%, val_loss:1.2428, val_acc:62.94%
#  Epoch 139: iteration 106/107
# Epoch 139 --> loss:0.1809, acc:94.07%, val_loss:1.2310, val_acc:62.94%
#  Epoch 140: iteration 106/107
# Epoch 140 --> loss:0.1864, acc:94.01%, val_loss:1.1062, val_acc:64.34%
#  Epoch 141: iteration 106/107
# Epoch 141 --> loss:0.1824, acc:94.07%, val_loss:1.2186, val_acc:65.03%
#  Epoch 142: iteration 106/107
# Epoch 142 --> loss:0.1849, acc:94.04%, val_loss:1.1923, val_acc:62.24%
#  Epoch 143: iteration 106/107
# Epoch 143 --> loss:0.1934, acc:93.37%, val_loss:1.1420, val_acc:63.64%
#  Epoch 144: iteration 106/107
# Epoch 144 --> loss:0.1701, acc:94.80%, val_loss:1.0586, val_acc:65.73%
#  Epoch 145: iteration 106/107
# Epoch 145 --> loss:0.1655, acc:95.09%, val_loss:1.0244, val_acc:65.73%
#  Epoch 146: iteration 106/107
# Epoch 146 --> loss:0.1723, acc:94.30%, val_loss:1.2840, val_acc:64.34%
#  Epoch 147: iteration 106/107
# Epoch 147 --> loss:0.1750, acc:94.30%, val_loss:1.2089, val_acc:65.03%
#  Epoch 148: iteration 106/107
# Epoch 148 --> loss:0.1678, acc:94.57%, val_loss:1.0817, val_acc:67.13%
#  Epoch 149: iteration 106/107
# Epoch 149 --> loss:0.1621, acc:94.97%, val_loss:1.3142, val_acc:61.54%
#  Epoch 150: iteration 106/107
# Epoch 150 --> loss:0.1817, acc:94.01%, val_loss:1.2376, val_acc:63.64%
#  Epoch 151: iteration 106/107
# Epoch 151 --> loss:0.1610, acc:95.03%, val_loss:1.1671, val_acc:64.34%
#  Epoch 152: iteration 106/107
# Epoch 152 --> loss:0.1728, acc:94.45%, val_loss:1.2592, val_acc:61.54%
#  Epoch 153: iteration 106/107
# Epoch 153 --> loss:0.1572, acc:95.26%, val_loss:1.2450, val_acc:66.43%
#  Epoch 154: iteration 106/107
# Epoch 154 --> loss:0.1578, acc:94.89%, val_loss:1.1973, val_acc:59.44%
#  Epoch 155: iteration 106/107
# Epoch 155 --> loss:0.1583, acc:94.94%, val_loss:1.1445, val_acc:67.13%
#  Epoch 156: iteration 106/107
# Epoch 156 --> loss:0.1628, acc:94.89%, val_loss:1.0846, val_acc:66.43%
#  Epoch 157: iteration 106/107
# Epoch 157 --> loss:0.1728, acc:94.16%, val_loss:1.2437, val_acc:61.54%
#  Epoch 158: iteration 106/107
# Epoch 158 --> loss:0.1641, acc:94.97%, val_loss:1.2222, val_acc:60.14%
#  Epoch 159: iteration 106/107
# Epoch 159 --> loss:0.1571, acc:95.00%, val_loss:1.0099, val_acc:65.73%
#  Epoch 160: iteration 106/107
# Epoch 160 --> loss:0.1602, acc:94.83%, val_loss:1.3766, val_acc:64.34%
#  Epoch 161: iteration 106/107
# Epoch 161 --> loss:0.1473, acc:95.00%, val_loss:1.0957, val_acc:65.73%
#  Epoch 162: iteration 106/107
# Epoch 162 --> loss:0.1476, acc:95.61%, val_loss:1.0916, val_acc:68.53%
#  Epoch 163: iteration 106/107
# Epoch 163 --> loss:0.1477, acc:95.35%, val_loss:1.1977, val_acc:64.34%
#  Epoch 164: iteration 106/107
# Epoch 164 --> loss:0.1518, acc:95.15%, val_loss:1.1975, val_acc:60.84%
#  Epoch 165: iteration 106/107
# Epoch 165 --> loss:0.1517, acc:95.12%, val_loss:1.2674, val_acc:60.84%
#  Epoch 166: iteration 106/107
# Epoch 166 --> loss:0.1445, acc:95.67%, val_loss:1.2408, val_acc:66.43%
#  Epoch 167: iteration 106/107
# Epoch 167 --> loss:0.1340, acc:96.11%, val_loss:1.2889, val_acc:63.64%
#  Epoch 168: iteration 106/107
# Epoch 168 --> loss:0.1391, acc:95.64%, val_loss:0.9607, val_acc:68.53%
#  Epoch 169: iteration 106/107
# Epoch 169 --> loss:0.1314, acc:95.79%, val_loss:1.0683, val_acc:67.13%
#  Epoch 170: iteration 106/107
# Epoch 170 --> loss:0.1397, acc:95.76%, val_loss:1.2955, val_acc:60.14%
#  Epoch 171: iteration 106/107
# Epoch 171 --> loss:0.1262, acc:96.34%, val_loss:1.1752, val_acc:65.73%
#  Epoch 172: iteration 106/107
# Epoch 172 --> loss:0.1282, acc:96.13%, val_loss:1.2445, val_acc:65.73%
#  Epoch 173: iteration 106/107
# Epoch 173 --> loss:0.1385, acc:95.35%, val_loss:1.0414, val_acc:67.13%
#  Epoch 174: iteration 106/107
# Epoch 174 --> loss:0.1361, acc:95.35%, val_loss:1.2629, val_acc:64.34%
#  Epoch 175: iteration 106/107
# Epoch 175 --> loss:0.1342, acc:95.32%, val_loss:1.0802, val_acc:67.83%
#  Epoch 176: iteration 106/107
# Epoch 176 --> loss:0.1446, acc:95.44%, val_loss:1.1450, val_acc:62.24%
#  Epoch 177: iteration 106/107
# Epoch 177 --> loss:0.1227, acc:96.19%, val_loss:1.0473, val_acc:65.73%
#  Epoch 178: iteration 106/107
# Epoch 178 --> loss:0.1223, acc:96.19%, val_loss:1.3379, val_acc:60.14%
#  Epoch 179: iteration 106/107
# Epoch 179 --> loss:0.1210, acc:96.37%, val_loss:1.2091, val_acc:61.54%
#  Epoch 180: iteration 106/107
# Epoch 180 --> loss:0.1229, acc:95.93%, val_loss:1.1224, val_acc:64.34%
#  Epoch 181: iteration 106/107
# Epoch 181 --> loss:0.1187, acc:96.25%, val_loss:0.9957, val_acc:67.83%
#  Epoch 182: iteration 106/107
# Epoch 182 --> loss:0.1195, acc:96.13%, val_loss:1.0389, val_acc:62.94%
#  Epoch 183: iteration 106/107
# Epoch 183 --> loss:0.1213, acc:96.31%, val_loss:1.1595, val_acc:67.83%
#  Epoch 184: iteration 106/107
# Epoch 184 --> loss:0.1109, acc:96.72%, val_loss:1.1801, val_acc:65.73%
#  Epoch 185: iteration 106/107
# Epoch 185 --> loss:0.1270, acc:96.25%, val_loss:1.1700, val_acc:58.04%
#  Epoch 186: iteration 106/107
# Epoch 186 --> loss:0.1199, acc:96.37%, val_loss:1.0956, val_acc:65.03%
#  Epoch 187: iteration 106/107
# Epoch 187 --> loss:0.1154, acc:96.51%, val_loss:1.1997, val_acc:61.54%
#  Epoch 188: iteration 106/107
# Epoch 188 --> loss:0.1179, acc:96.16%, val_loss:1.1696, val_acc:65.03%
#  Epoch 189: iteration 106/107
# Epoch 189 --> loss:0.1208, acc:96.11%, val_loss:1.0548, val_acc:65.03%
#  Epoch 190: iteration 106/107
# Epoch 190 --> loss:0.1225, acc:96.08%, val_loss:1.0640, val_acc:66.43%
#  Epoch 191: iteration 106/107
# Epoch 191 --> loss:0.1205, acc:96.05%, val_loss:1.1055, val_acc:64.34%
#  Epoch 192: iteration 106/107
# Epoch 192 --> loss:0.1055, acc:97.04%, val_loss:1.1400, val_acc:62.94%
#  Epoch 193: iteration 106/107
# Epoch 193 --> loss:0.1086, acc:96.66%, val_loss:1.2372, val_acc:62.94%
#  Epoch 194: iteration 106/107
# Epoch 194 --> loss:0.1079, acc:96.48%, val_loss:1.0780, val_acc:65.03%
#  Epoch 195: iteration 106/107
# Epoch 195 --> loss:0.1119, acc:96.57%, val_loss:1.2674, val_acc:62.24%
#  Epoch 196: iteration 106/107
# Epoch 196 --> loss:0.1056, acc:96.89%, val_loss:1.1759, val_acc:65.03%
#  Epoch 197: iteration 106/107
# Epoch 197 --> loss:0.1168, acc:95.99%, val_loss:1.1325, val_acc:63.64%
#  Epoch 198: iteration 106/107
# Epoch 198 --> loss:0.0991, acc:97.06%, val_loss:1.2647, val_acc:62.94%
#  Epoch 199: iteration 106/107
# Epoch 199 --> loss:0.1064, acc:96.77%, val_loss:1.2332, val_acc:63.64%
#  Epoch 200: iteration 106/107
# Epoch 200 --> loss:0.1065, acc:96.69%, val_loss:1.2150, val_acc:65.03%
#  Epoch 201: iteration 106/107
# Epoch 201 --> loss:0.0986, acc:97.09%, val_loss:1.1804, val_acc:62.94%
#  Epoch 202: iteration 106/107
# Epoch 202 --> loss:0.0987, acc:97.18%, val_loss:1.1336, val_acc:65.03%
#  Epoch 203: iteration 106/107
# Epoch 203 --> loss:0.0946, acc:97.56%, val_loss:1.1370, val_acc:64.34%
#  Epoch 204: iteration 106/107
# Epoch 204 --> loss:0.1073, acc:96.63%, val_loss:1.0974, val_acc:63.64%
#  Epoch 205: iteration 106/107
# Epoch 205 --> loss:0.0913, acc:97.30%, val_loss:1.1479, val_acc:67.83%
#  Epoch 206: iteration 106/107
# Epoch 206 --> loss:0.0996, acc:97.06%, val_loss:1.0477, val_acc:67.13%
#  Epoch 207: iteration 106/107
# Epoch 207 --> loss:0.0987, acc:96.72%, val_loss:1.0987, val_acc:67.83%
#  Epoch 208: iteration 106/107
# Epoch 208 --> loss:0.1087, acc:96.80%, val_loss:1.0975, val_acc:64.34%
#  Epoch 209: iteration 106/107
# Epoch 209 --> loss:0.1064, acc:96.54%, val_loss:1.1239, val_acc:63.64%
#  Epoch 210: iteration 106/107
# Epoch 210 --> loss:0.1081, acc:96.86%, val_loss:1.0943, val_acc:67.83%
#  Epoch 211: iteration 106/107
# Epoch 211 --> loss:0.1072, acc:96.63%, val_loss:1.1940, val_acc:67.13%
#  Epoch 212: iteration 106/107
# Epoch 212 --> loss:0.0952, acc:97.36%, val_loss:1.1637, val_acc:62.94%
#  Epoch 213: iteration 106/107
# Epoch 213 --> loss:0.0943, acc:97.27%, val_loss:1.2382, val_acc:58.04%
#  Epoch 214: iteration 106/107
# Epoch 214 --> loss:0.0931, acc:97.12%, val_loss:1.1572, val_acc:67.13%
#  Epoch 215: iteration 106/107
# Epoch 215 --> loss:0.0966, acc:97.01%, val_loss:1.1002, val_acc:67.13%
#  Epoch 216: iteration 106/107
# Epoch 216 --> loss:0.0916, acc:97.15%, val_loss:1.1335, val_acc:64.34%
#  Epoch 217: iteration 106/107
# Epoch 217 --> loss:0.0945, acc:97.04%, val_loss:1.0484, val_acc:64.34%
#  Epoch 218: iteration 106/107
# Epoch 218 --> loss:0.1008, acc:96.92%, val_loss:1.0863, val_acc:67.83%
#  Epoch 219: iteration 106/107
# Epoch 219 --> loss:0.0869, acc:97.53%, val_loss:1.0406, val_acc:68.53%
#  Epoch 220: iteration 106/107
# Epoch 220 --> loss:0.0962, acc:97.18%, val_loss:1.3412, val_acc:58.74%
#  Epoch 221: iteration 106/107
# Epoch 221 --> loss:0.0884, acc:97.59%, val_loss:1.3479, val_acc:60.84%
#  Epoch 222: iteration 106/107
# Epoch 222 --> loss:0.0971, acc:96.92%, val_loss:1.3455, val_acc:62.24%
#  Epoch 223: iteration 106/107
# Epoch 223 --> loss:0.0962, acc:97.01%, val_loss:1.0320, val_acc:67.13%
#  Epoch 224: iteration 106/107
# Epoch 224 --> loss:0.0926, acc:97.21%, val_loss:1.2111, val_acc:61.54%
#  Epoch 225: iteration 106/107
# Epoch 225 --> loss:0.0983, acc:97.04%, val_loss:1.2469, val_acc:67.13%
#  Epoch 226: iteration 106/107
# Epoch 226 --> loss:0.0829, acc:97.59%, val_loss:1.1405, val_acc:64.34%
#  Epoch 227: iteration 106/107
# Epoch 227 --> loss:0.0957, acc:97.06%, val_loss:1.0852, val_acc:67.13%
#  Epoch 228: iteration 106/107
# Epoch 228 --> loss:0.0915, acc:97.27%, val_loss:1.1752, val_acc:62.94%
#  Epoch 229: iteration 106/107
# Epoch 229 --> loss:0.0948, acc:97.24%, val_loss:1.3457, val_acc:58.04%
#  Epoch 230: iteration 106/107
# Epoch 230 --> loss:0.0897, acc:97.36%, val_loss:1.2323, val_acc:64.34%
#  Epoch 231: iteration 106/107
# Epoch 231 --> loss:0.0878, acc:97.36%, val_loss:1.1973, val_acc:61.54%
#  Epoch 232: iteration 106/107
# Epoch 232 --> loss:0.0928, acc:96.95%, val_loss:1.0663, val_acc:65.73%
#  Epoch 233: iteration 106/107
# Epoch 233 --> loss:0.0816, acc:97.65%, val_loss:1.1830, val_acc:66.43%
#  Epoch 234: iteration 106/107
# Epoch 234 --> loss:0.0834, acc:97.47%, val_loss:1.1324, val_acc:65.03%
#  Epoch 235: iteration 106/107
# Epoch 235 --> loss:0.0891, acc:97.56%, val_loss:1.0995, val_acc:64.34%
#  Epoch 236: iteration 106/107
# Epoch 236 --> loss:0.1088, acc:96.54%, val_loss:1.1377, val_acc:66.43%
#  Epoch 237: iteration 106/107
# Epoch 237 --> loss:0.0950, acc:97.15%, val_loss:1.1608, val_acc:63.64%
#  Epoch 238: iteration 106/107
# Epoch 238 --> loss:0.0839, acc:97.82%, val_loss:1.1566, val_acc:64.34%
#  Epoch 239: iteration 106/107
# Epoch 239 --> loss:0.0824, acc:97.41%, val_loss:1.2714, val_acc:63.64%
#  Epoch 240: iteration 106/107
# Epoch 240 --> loss:0.0960, acc:97.04%, val_loss:1.1417, val_acc:62.94%
#  Epoch 241: iteration 106/107
# Epoch 241 --> loss:0.0783, acc:97.99%, val_loss:1.1419, val_acc:69.23%
#  Epoch 242: iteration 106/107
# Epoch 242 --> loss:0.0836, acc:97.44%, val_loss:1.4663, val_acc:56.64%
#  Epoch 243: iteration 106/107
# Epoch 243 --> loss:0.0890, acc:97.47%, val_loss:1.0918, val_acc:67.13%
#  Epoch 244: iteration 106/107
# Epoch 244 --> loss:0.0830, acc:97.50%, val_loss:1.1296, val_acc:67.83%
#  Epoch 245: iteration 106/107
# Epoch 245 --> loss:0.0843, acc:97.50%, val_loss:1.0859, val_acc:66.43%
#  Epoch 246: iteration 106/107
# Epoch 246 --> loss:0.0739, acc:98.17%, val_loss:1.1188, val_acc:67.83%
#  Epoch 247: iteration 106/107
# Epoch 247 --> loss:0.0835, acc:97.50%, val_loss:1.1217, val_acc:62.94%
#  Epoch 248: iteration 106/107
# Epoch 248 --> loss:0.0867, acc:97.30%, val_loss:1.2504, val_acc:61.54%
#  Epoch 249: iteration 106/107
# Epoch 249 --> loss:0.0777, acc:97.76%, val_loss:1.0580, val_acc:67.83%
#  Epoch 250: iteration 106/107
# Epoch 250 --> loss:0.0875, acc:97.09%, val_loss:1.2023, val_acc:63.64%
#  Epoch 251: iteration 106/107
# Epoch 251 --> loss:0.0830, acc:97.62%, val_loss:1.1007, val_acc:66.43%
#  Epoch 252: iteration 106/107
# Epoch 252 --> loss:0.0690, acc:98.29%, val_loss:1.0583, val_acc:62.24%
#  Epoch 253: iteration 106/107
# Epoch 253 --> loss:0.0907, acc:97.18%, val_loss:1.2286, val_acc:63.64%
#  Epoch 254: iteration 106/107
# Epoch 254 --> loss:0.0790, acc:97.73%, val_loss:1.1141, val_acc:65.73%
#  Epoch 255: iteration 106/107
# Epoch 255 --> loss:0.0863, acc:97.44%, val_loss:1.1038, val_acc:65.03%
#  Epoch 256: iteration 106/107
# Epoch 256 --> loss:0.0910, acc:97.12%, val_loss:1.0567, val_acc:64.34%
#  Epoch 257: iteration 106/107
# Epoch 257 --> loss:0.0790, acc:97.56%, val_loss:1.0794, val_acc:62.94%
#  Epoch 258: iteration 106/107
# Epoch 258 --> loss:0.0840, acc:97.21%, val_loss:1.1729, val_acc:62.24%
#  Epoch 259: iteration 106/107
# Epoch 259 --> loss:0.0830, acc:97.73%, val_loss:1.1311, val_acc:67.13%
#  Epoch 260: iteration 106/107
# Epoch 260 --> loss:0.0735, acc:98.08%, val_loss:1.0657, val_acc:65.73%
#  Epoch 261: iteration 106/107
# Epoch 261 --> loss:0.0818, acc:97.76%, val_loss:1.1073, val_acc:62.24%
#  Epoch 262: iteration 106/107
# Epoch 262 --> loss:0.0914, acc:97.15%, val_loss:1.2516, val_acc:64.34%
#  Epoch 263: iteration 106/107
# Epoch 263 --> loss:0.0862, acc:97.50%, val_loss:1.2174, val_acc:66.43%
#  Epoch 264: iteration 106/107
# Epoch 264 --> loss:0.0835, acc:97.56%, val_loss:1.1281, val_acc:69.23%
#  Epoch 265: iteration 106/107
# Epoch 265 --> loss:0.0910, acc:97.01%, val_loss:1.0225, val_acc:61.54%
#  Epoch 266: iteration 106/107
# Epoch 266 --> loss:0.0755, acc:97.99%, val_loss:1.3131, val_acc:60.14%
#  Epoch 267: iteration 106/107
# Epoch 267 --> loss:0.0902, acc:97.27%, val_loss:1.0795, val_acc:63.64%
#  Epoch 268: iteration 106/107
# Epoch 268 --> loss:0.0717, acc:98.08%, val_loss:1.1630, val_acc:63.64%
#  Epoch 269: iteration 106/107
# Epoch 269 --> loss:0.0704, acc:97.85%, val_loss:1.0800, val_acc:64.34%
#  Epoch 270: iteration 106/107
# Epoch 270 --> loss:0.0708, acc:98.08%, val_loss:1.3238, val_acc:60.84%
#  Epoch 271: iteration 106/107
# Epoch 271 --> loss:0.0767, acc:97.68%, val_loss:1.1314, val_acc:67.83%
#  Epoch 272: iteration 106/107
# Epoch 272 --> loss:0.0919, acc:97.04%, val_loss:1.0580, val_acc:67.13%
#  Epoch 273: iteration 106/107
# Epoch 273 --> loss:0.0675, acc:98.23%, val_loss:1.1145, val_acc:61.54%
#  Epoch 274: iteration 106/107
# Epoch 274 --> loss:0.0756, acc:97.97%, val_loss:1.1661, val_acc:67.13%
#  Epoch 275: iteration 106/107
# Epoch 275 --> loss:0.0714, acc:97.99%, val_loss:1.1804, val_acc:67.13%
#  Epoch 276: iteration 106/107
# Epoch 276 --> loss:0.0747, acc:97.68%, val_loss:1.1431, val_acc:62.94%
#  Epoch 277: iteration 106/107
# Epoch 277 --> loss:0.0706, acc:98.14%, val_loss:1.1806, val_acc:66.43%
#  Epoch 278: iteration 106/107
# Epoch 278 --> loss:0.0660, acc:98.17%, val_loss:1.1637, val_acc:62.24%
#  Epoch 279: iteration 106/107
# Epoch 279 --> loss:0.0752, acc:97.70%, val_loss:1.1125, val_acc:61.54%
#  Epoch 280: iteration 106/107
# Epoch 280 --> loss:0.0804, acc:97.53%, val_loss:1.0916, val_acc:64.34%
#  Epoch 281: iteration 106/107
# Epoch 281 --> loss:0.0804, acc:97.73%, val_loss:1.0251, val_acc:67.13%
#  Epoch 282: iteration 106/107
# Epoch 282 --> loss:0.0766, acc:97.85%, val_loss:1.1359, val_acc:65.73%
#  Epoch 283: iteration 106/107
# Epoch 283 --> loss:0.0707, acc:97.94%, val_loss:1.2040, val_acc:66.43%
#  Epoch 284: iteration 106/107
# Epoch 284 --> loss:0.0729, acc:97.85%, val_loss:1.3531, val_acc:61.54%
#  Epoch 285: iteration 106/107
# Epoch 285 --> loss:0.0595, acc:98.46%, val_loss:1.1470, val_acc:65.03%
#  Epoch 286: iteration 106/107
# Epoch 286 --> loss:0.0762, acc:97.56%, val_loss:1.3025, val_acc:63.64%
#  Epoch 287: iteration 106/107
# Epoch 287 --> loss:0.0783, acc:97.53%, val_loss:1.1581, val_acc:66.43%
#  Epoch 288: iteration 106/107
# Epoch 288 --> loss:0.0659, acc:98.23%, val_loss:1.1811, val_acc:60.14%
#  Epoch 289: iteration 106/107
# Epoch 289 --> loss:0.0672, acc:97.97%, val_loss:1.0714, val_acc:65.03%
#  Epoch 290: iteration 106/107
# Epoch 290 --> loss:0.0689, acc:98.02%, val_loss:1.1030, val_acc:66.43%
#  Epoch 291: iteration 106/107
# Epoch 291 --> loss:0.0873, acc:97.21%, val_loss:1.3375, val_acc:60.84%
#  Epoch 292: iteration 106/107
# Epoch 292 --> loss:0.0693, acc:98.05%, val_loss:1.5380, val_acc:55.94%
#  Epoch 293: iteration 106/107
# Epoch 293 --> loss:0.0781, acc:97.47%, val_loss:1.3088, val_acc:56.64%
#  Epoch 294: iteration 106/107
# Epoch 294 --> loss:0.0737, acc:97.97%, val_loss:1.1788, val_acc:62.24%
#  Epoch 295: iteration 106/107
# Epoch 295 --> loss:0.0765, acc:97.70%, val_loss:1.0898, val_acc:60.84%
#  Epoch 296: iteration 106/107
# Epoch 296 --> loss:0.0718, acc:98.08%, val_loss:1.0318, val_acc:68.53%
#  Epoch 297: iteration 106/107
# Epoch 297 --> loss:0.0658, acc:98.05%, val_loss:1.2074, val_acc:61.54%
#  Epoch 298: iteration 106/107
# Epoch 298 --> loss:0.0821, acc:97.47%, val_loss:1.1461, val_acc:63.64%
#  Epoch 299: iteration 106/107
# Epoch 299 --> loss:0.0686, acc:98.08%, val_loss:1.2906, val_acc:62.24%
#  Epoch 300: iteration 106/107
# Epoch 300 --> loss:0.0723, acc:97.91%, val_loss:1.3128, val_acc:60.14%
#  Epoch 301: iteration 106/107
# Epoch 301 --> loss:0.0842, acc:97.24%, val_loss:1.1752, val_acc:65.73%
#  Epoch 302: iteration 106/107
# Epoch 302 --> loss:0.0977, acc:96.89%, val_loss:1.1038, val_acc:65.03%
#  Epoch 303: iteration 106/107
# Epoch 303 --> loss:0.0782, acc:97.68%, val_loss:1.1256, val_acc:62.94%
#  Epoch 304: iteration 106/107
# Epoch 304 --> loss:0.0703, acc:97.91%, val_loss:1.1173, val_acc:68.53%
#  Epoch 305: iteration 106/107
# Epoch 305 --> loss:0.0746, acc:97.94%, val_loss:1.2135, val_acc:63.64%
#  Epoch 306: iteration 106/107
# Epoch 306 --> loss:0.0767, acc:97.47%, val_loss:1.4041, val_acc:62.94%
#  Epoch 307: iteration 106/107
# Epoch 307 --> loss:0.0639, acc:98.08%, val_loss:1.3053, val_acc:60.84%
#  Epoch 308: iteration 106/107
# Epoch 308 --> loss:0.0908, acc:97.21%, val_loss:0.9954, val_acc:65.03%
#  Epoch 309: iteration 106/107
# Epoch 309 --> loss:0.0732, acc:97.76%, val_loss:1.1142, val_acc:65.73%
#  Epoch 310: iteration 106/107
# Epoch 310 --> loss:0.0682, acc:98.05%, val_loss:1.0441, val_acc:65.73%
#  Epoch 311: iteration 106/107
# Epoch 311 --> loss:0.0678, acc:97.91%, val_loss:1.1240, val_acc:62.24%
#  Epoch 312: iteration 106/107
# Epoch 312 --> loss:0.0683, acc:97.97%, val_loss:1.0759, val_acc:67.13%
#  Epoch 313: iteration 106/107
# Epoch 313 --> loss:0.0744, acc:97.50%, val_loss:1.3548, val_acc:55.94%
#  Epoch 314: iteration 106/107
# Epoch 314 --> loss:0.0637, acc:98.40%, val_loss:1.0651, val_acc:64.34%
#  Epoch 315: iteration 106/107
# Epoch 315 --> loss:0.0680, acc:97.99%, val_loss:1.1616, val_acc:64.34%
#  Epoch 316: iteration 106/107
# Epoch 316 --> loss:0.0747, acc:97.85%, val_loss:1.1162, val_acc:67.83%
#  Epoch 317: iteration 106/107
# Epoch 317 --> loss:0.0786, acc:97.53%, val_loss:1.1936, val_acc:65.03%
#  Epoch 318: iteration 106/107
# Epoch 318 --> loss:0.0830, acc:97.68%, val_loss:1.0405, val_acc:64.34%
#  Epoch 319: iteration 106/107
# Epoch 319 --> loss:0.0687, acc:98.08%, val_loss:1.0176, val_acc:64.34%
#  Epoch 320: iteration 106/107
# Epoch 320 --> loss:0.0599, acc:98.46%, val_loss:1.0375, val_acc:68.53%
#  Epoch 321: iteration 106/107
# Epoch 321 --> loss:0.0673, acc:98.11%, val_loss:1.1983, val_acc:61.54%
#  Epoch 322: iteration 106/107
# Epoch 322 --> loss:0.0705, acc:98.23%, val_loss:1.2411, val_acc:63.64%
#  Epoch 323: iteration 106/107
# Epoch 323 --> loss:0.0779, acc:97.73%, val_loss:1.0576, val_acc:60.14%
#  Epoch 324: iteration 106/107
# Epoch 324 --> loss:0.0726, acc:97.85%, val_loss:1.2016, val_acc:67.83%
#  Epoch 325: iteration 106/107
# Epoch 325 --> loss:0.0692, acc:98.14%, val_loss:1.0797, val_acc:62.94%
#  Epoch 326: iteration 106/107
# Epoch 326 --> loss:0.0685, acc:98.05%, val_loss:1.1180, val_acc:66.43%
#  Epoch 327: iteration 106/107
# Epoch 327 --> loss:0.0737, acc:97.70%, val_loss:1.3802, val_acc:55.24%
#  Epoch 328: iteration 106/107
# Epoch 328 --> loss:0.0754, acc:97.68%, val_loss:1.1314, val_acc:64.34%
#  Epoch 329: iteration 106/107
# Epoch 329 --> loss:0.0594, acc:98.34%, val_loss:1.1288, val_acc:65.73%
#  Epoch 330: iteration 106/107
# Epoch 330 --> loss:0.0564, acc:98.43%, val_loss:1.0919, val_acc:65.73%
#  Epoch 331: iteration 106/107
# Epoch 331 --> loss:0.0651, acc:98.05%, val_loss:0.9771, val_acc:69.23%
#  Epoch 332: iteration 106/107
# Epoch 332 --> loss:0.0575, acc:98.37%, val_loss:1.0789, val_acc:66.43%
#  Epoch 333: iteration 106/107
# Epoch 333 --> loss:0.0769, acc:97.38%, val_loss:1.0983, val_acc:66.43%
#  Epoch 334: iteration 106/107
# Epoch 334 --> loss:0.0581, acc:98.58%, val_loss:1.1788, val_acc:65.03%
#  Epoch 335: iteration 106/107
# Epoch 335 --> loss:0.0768, acc:97.76%, val_loss:1.3055, val_acc:60.84%
#  Epoch 336: iteration 106/107
# Epoch 336 --> loss:0.0562, acc:98.61%, val_loss:1.0610, val_acc:67.13%
#  Epoch 337: iteration 106/107
# Epoch 337 --> loss:0.0574, acc:98.46%, val_loss:0.9542, val_acc:66.43%
#  Epoch 338: iteration 106/107
# Epoch 338 --> loss:0.0590, acc:98.29%, val_loss:1.1528, val_acc:62.94%
#  Epoch 339: iteration 106/107
# Epoch 339 --> loss:0.0638, acc:98.17%, val_loss:1.1412, val_acc:62.94%
#  Epoch 340: iteration 106/107
# Epoch 340 --> loss:0.0881, acc:97.33%, val_loss:1.0608, val_acc:69.23%
#  Epoch 341: iteration 106/107
# Epoch 341 --> loss:0.0790, acc:97.70%, val_loss:1.0697, val_acc:67.83%
#  Epoch 342: iteration 106/107
# Epoch 342 --> loss:0.0796, acc:97.82%, val_loss:1.0988, val_acc:67.83%
#  Epoch 343: iteration 106/107
# Epoch 343 --> loss:0.0617, acc:98.11%, val_loss:1.0690, val_acc:67.83%
#  Epoch 344: iteration 106/107
# Epoch 344 --> loss:0.0674, acc:98.08%, val_loss:0.9937, val_acc:67.83%
#  Epoch 345: iteration 106/107
# Epoch 345 --> loss:0.0596, acc:98.46%, val_loss:1.0960, val_acc:62.94%
#  Epoch 346: iteration 106/107
# Epoch 346 --> loss:0.0554, acc:98.43%, val_loss:1.2368, val_acc:60.84%
#  Epoch 347: iteration 106/107
# Epoch 347 --> loss:0.0526, acc:98.75%, val_loss:1.1250, val_acc:65.73%
#  Epoch 348: iteration 106/107
# Epoch 348 --> loss:0.0684, acc:98.34%, val_loss:1.0351, val_acc:63.64%
#  Epoch 349: iteration 106/107
# Epoch 349 --> loss:0.0698, acc:98.17%, val_loss:1.0339, val_acc:67.13%
#  Epoch 350: iteration 106/107
# Epoch 350 --> loss:0.0671, acc:98.08%, val_loss:1.0680, val_acc:69.23%
#  Epoch 351: iteration 106/107
# Epoch 351 --> loss:0.0658, acc:97.82%, val_loss:1.3019, val_acc:64.34%
#  Epoch 352: iteration 106/107
# Epoch 352 --> loss:0.0756, acc:97.73%, val_loss:1.1680, val_acc:65.03%
#  Epoch 353: iteration 106/107
# Epoch 353 --> loss:0.0614, acc:98.14%, val_loss:1.0712, val_acc:64.34%
#  Epoch 354: iteration 106/107
# Epoch 354 --> loss:0.0857, acc:97.15%, val_loss:1.1389, val_acc:62.94%
#  Epoch 355: iteration 106/107
# Epoch 355 --> loss:0.0635, acc:98.49%, val_loss:0.9630, val_acc:68.53%
#  Epoch 356: iteration 106/107
# Epoch 356 --> loss:0.0746, acc:97.70%, val_loss:1.1205, val_acc:70.63%
#  Epoch 357: iteration 106/107
# Epoch 357 --> loss:0.0670, acc:98.26%, val_loss:1.0250, val_acc:65.03%
#  Epoch 358: iteration 106/107
# Epoch 358 --> loss:0.0644, acc:98.34%, val_loss:1.0530, val_acc:64.34%
#  Epoch 359: iteration 106/107
# Epoch 359 --> loss:0.0712, acc:98.08%, val_loss:1.0273, val_acc:67.83%
#  Epoch 360: iteration 106/107
# Epoch 360 --> loss:0.0664, acc:98.11%, val_loss:1.1756, val_acc:63.64%
#  Epoch 361: iteration 106/107
# Epoch 361 --> loss:0.0761, acc:97.53%, val_loss:1.2117, val_acc:63.64%
#  Epoch 362: iteration 106/107
# Epoch 362 --> loss:0.0684, acc:97.79%, val_loss:1.0273, val_acc:65.73%
#  Epoch 363: iteration 106/107
# Epoch 363 --> loss:0.0881, acc:97.18%, val_loss:1.0064, val_acc:67.13%
#  Epoch 364: iteration 106/107
# Epoch 364 --> loss:0.0644, acc:98.40%, val_loss:1.0366, val_acc:67.83%
#  Epoch 365: iteration 106/107
# Epoch 365 --> loss:0.0706, acc:97.59%, val_loss:1.0634, val_acc:68.53%
#  Epoch 366: iteration 106/107
# Epoch 366 --> loss:0.0602, acc:98.52%, val_loss:1.0171, val_acc:69.23%
#  Epoch 367: iteration 106/107
# Epoch 367 --> loss:0.0709, acc:97.68%, val_loss:1.0311, val_acc:65.03%
#  Epoch 368: iteration 106/107
# Epoch 368 --> loss:0.0585, acc:98.31%, val_loss:1.1425, val_acc:67.13%
#  Epoch 369: iteration 106/107
# Epoch 369 --> loss:0.0619, acc:98.20%, val_loss:1.0779, val_acc:67.83%
#  Epoch 370: iteration 106/107
# Epoch 370 --> loss:0.0544, acc:98.55%, val_loss:1.0410, val_acc:67.83%
#  Epoch 371: iteration 106/107
# Epoch 371 --> loss:0.0645, acc:98.17%, val_loss:1.1269, val_acc:62.94%
#  Epoch 372: iteration 106/107
# Epoch 372 --> loss:0.0616, acc:98.31%, val_loss:1.1807, val_acc:65.73%
#  Epoch 373: iteration 106/107
# Epoch 373 --> loss:0.0684, acc:97.85%, val_loss:1.0296, val_acc:66.43%
#  Epoch 374: iteration 106/107
# Epoch 374 --> loss:0.0671, acc:97.79%, val_loss:1.1871, val_acc:63.64%
#  Epoch 375: iteration 106/107
# Epoch 375 --> loss:0.0631, acc:98.23%, val_loss:1.1038, val_acc:65.73%
#  Epoch 376: iteration 106/107
# Epoch 376 --> loss:0.0688, acc:98.02%, val_loss:1.2296, val_acc:62.24%
#  Epoch 377: iteration 106/107
# Epoch 377 --> loss:0.0649, acc:98.14%, val_loss:1.0337, val_acc:67.13%
#  Epoch 378: iteration 106/107
# Epoch 378 --> loss:0.0632, acc:98.23%, val_loss:1.0285, val_acc:67.83%
#  Epoch 379: iteration 106/107
# Epoch 379 --> loss:0.0559, acc:98.72%, val_loss:1.0348, val_acc:65.03%
#  Epoch 380: iteration 106/107
# Epoch 380 --> loss:0.0606, acc:98.17%, val_loss:0.9891, val_acc:67.83%
#  Epoch 381: iteration 106/107
# Epoch 381 --> loss:0.0631, acc:98.02%, val_loss:1.0434, val_acc:69.93%
#  Epoch 382: iteration 106/107
# Epoch 382 --> loss:0.0583, acc:98.49%, val_loss:1.1539, val_acc:65.03%
#  Epoch 383: iteration 106/107
# Epoch 383 --> loss:0.0600, acc:98.31%, val_loss:1.1542, val_acc:68.53%
#  Epoch 384: iteration 106/107
# Epoch 384 --> loss:0.0550, acc:98.43%, val_loss:1.0728, val_acc:63.64%
#  Epoch 385: iteration 106/107
# Epoch 385 --> loss:0.0648, acc:98.14%, val_loss:1.1318, val_acc:64.34%
#  Epoch 386: iteration 106/107
# Epoch 386 --> loss:0.0665, acc:98.11%, val_loss:1.0858, val_acc:65.73%
#  Epoch 387: iteration 106/107
# Epoch 387 --> loss:0.0610, acc:98.29%, val_loss:1.0386, val_acc:64.34%
#  Epoch 388: iteration 106/107
# Epoch 388 --> loss:0.0675, acc:97.85%, val_loss:1.0658, val_acc:64.34%
#  Epoch 389: iteration 106/107
# Epoch 389 --> loss:0.0613, acc:98.31%, val_loss:1.1479, val_acc:68.53%
#  Epoch 390: iteration 106/107
# Epoch 390 --> loss:0.0853, acc:97.33%, val_loss:1.0880, val_acc:63.64%
#  Epoch 391: iteration 106/107
# Epoch 391 --> loss:0.0629, acc:97.97%, val_loss:0.9660, val_acc:67.83%
#  Epoch 392: iteration 106/107
# Epoch 392 --> loss:0.0721, acc:97.68%, val_loss:1.3012, val_acc:58.74%
#  Epoch 393: iteration 106/107
# Epoch 393 --> loss:0.0549, acc:98.66%, val_loss:1.1273, val_acc:65.73%
#  Epoch 394: iteration 106/107
# Epoch 394 --> loss:0.0646, acc:97.79%, val_loss:1.2243, val_acc:62.94%
#  Epoch 395: iteration 106/107
# Epoch 395 --> loss:0.0604, acc:98.23%, val_loss:1.2218, val_acc:62.24%
#  Epoch 396: iteration 106/107
# Epoch 396 --> loss:0.0623, acc:98.26%, val_loss:1.1520, val_acc:65.73%
#  Epoch 397: iteration 106/107
# Epoch 397 --> loss:0.0563, acc:98.34%, val_loss:1.1805, val_acc:62.94%
#  Epoch 398: iteration 106/107
# Epoch 398 --> loss:0.0708, acc:97.88%, val_loss:0.9518, val_acc:68.53%
#  Epoch 399: iteration 106/107
# Epoch 399 --> loss:0.0913, acc:97.06%, val_loss:1.0490, val_acc:59.44%
#  Epoch 400: iteration 106/107
# Epoch 400 --> loss:0.0727, acc:98.02%, val_loss:1.1229, val_acc:62.94%
#  Epoch 401: iteration 106/107
# Epoch 401 --> loss:0.0682, acc:98.20%, val_loss:1.2201, val_acc:62.94%
#  Epoch 402: iteration 106/107
# Epoch 402 --> loss:0.0618, acc:98.26%, val_loss:1.1737, val_acc:62.24%
#  Epoch 403: iteration 106/107
# Epoch 403 --> loss:0.0569, acc:98.31%, val_loss:1.2120, val_acc:65.73%
#  Epoch 404: iteration 106/107
# Epoch 404 --> loss:0.0514, acc:98.72%, val_loss:1.0157, val_acc:65.73%
#  Epoch 405: iteration 106/107
# Epoch 405 --> loss:0.0674, acc:97.82%, val_loss:1.1481, val_acc:62.24%
#  Epoch 406: iteration 106/107
# Epoch 406 --> loss:0.0681, acc:97.79%, val_loss:1.1294, val_acc:67.13%
#  Epoch 407: iteration 106/107
# Epoch 407 --> loss:0.0672, acc:97.88%, val_loss:1.1393, val_acc:66.43%
#  Epoch 408: iteration 106/107
# Epoch 408 --> loss:0.0554, acc:98.43%, val_loss:1.1801, val_acc:63.64%
#  Epoch 409: iteration 106/107
# Epoch 409 --> loss:0.0879, acc:97.36%, val_loss:1.0818, val_acc:65.73%
#  Epoch 410: iteration 106/107
# Epoch 410 --> loss:0.0621, acc:98.29%, val_loss:1.1004, val_acc:63.64%
#  Epoch 411: iteration 106/107
# Epoch 411 --> loss:0.0614, acc:98.11%, val_loss:0.9925, val_acc:66.43%
#  Epoch 412: iteration 106/107
# Epoch 412 --> loss:0.0502, acc:98.63%, val_loss:1.0081, val_acc:65.73%
#  Epoch 413: iteration 106/107
# Epoch 413 --> loss:0.0534, acc:98.49%, val_loss:1.0461, val_acc:64.34%
#  Epoch 414: iteration 106/107
# Epoch 414 --> loss:0.0689, acc:97.91%, val_loss:1.1853, val_acc:61.54%
#  Epoch 415: iteration 106/107
# Epoch 415 --> loss:0.0598, acc:98.20%, val_loss:1.1926, val_acc:62.94%
#  Epoch 416: iteration 106/107
# Epoch 416 --> loss:0.0663, acc:97.91%, val_loss:0.9847, val_acc:69.93%
#  Epoch 417: iteration 106/107
# Epoch 417 --> loss:0.0556, acc:98.63%, val_loss:1.3227, val_acc:61.54%
#  Epoch 418: iteration 106/107
# Epoch 418 --> loss:0.0514, acc:98.66%, val_loss:1.0344, val_acc:67.13%
#  Epoch 419: iteration 106/107
# Epoch 419 --> loss:0.0670, acc:97.97%, val_loss:1.2177, val_acc:67.13%
#  Epoch 420: iteration 106/107
# Epoch 420 --> loss:0.0515, acc:98.75%, val_loss:1.0537, val_acc:65.03%
#  Epoch 421: iteration 106/107
# Epoch 421 --> loss:0.0531, acc:98.37%, val_loss:1.1007, val_acc:63.64%
#  Epoch 422: iteration 106/107
# Epoch 422 --> loss:0.0530, acc:98.55%, val_loss:1.2272, val_acc:64.34%
#  Epoch 423: iteration 106/107
# Epoch 423 --> loss:0.0527, acc:98.52%, val_loss:1.1524, val_acc:65.73%
#  Epoch 424: iteration 106/107
# Epoch 424 --> loss:0.0571, acc:98.31%, val_loss:1.2637, val_acc:63.64%
#  Epoch 425: iteration 106/107
# Epoch 425 --> loss:0.0636, acc:97.99%, val_loss:1.1658, val_acc:68.53%
#  Epoch 426: iteration 106/107
# Epoch 426 --> loss:0.0567, acc:98.49%, val_loss:1.0017, val_acc:67.83%
#  Epoch 427: iteration 106/107
# Epoch 427 --> loss:0.0673, acc:98.08%, val_loss:1.0701, val_acc:65.03%
#  Epoch 428: iteration 106/107
# Epoch 428 --> loss:0.0479, acc:98.81%, val_loss:1.0217, val_acc:69.23%
#  Epoch 429: iteration 106/107
# Epoch 429 --> loss:0.0591, acc:98.40%, val_loss:1.0023, val_acc:67.13%
#  Epoch 430: iteration 106/107
# Epoch 430 --> loss:0.0701, acc:97.65%, val_loss:1.1744, val_acc:65.03%
#  Epoch 431: iteration 106/107
# Epoch 431 --> loss:0.0670, acc:98.08%, val_loss:1.1007, val_acc:63.64%
#  Epoch 432: iteration 106/107
# Epoch 432 --> loss:0.0514, acc:98.61%, val_loss:1.1310, val_acc:66.43%
#  Epoch 433: iteration 106/107
# Epoch 433 --> loss:0.0565, acc:98.37%, val_loss:1.0310, val_acc:67.13%
#  Epoch 434: iteration 106/107
# Epoch 434 --> loss:0.0627, acc:98.23%, val_loss:1.2845, val_acc:63.64%
#  Epoch 435: iteration 106/107
# Epoch 435 --> loss:0.0534, acc:98.52%, val_loss:1.2286, val_acc:64.34%
#  Epoch 436: iteration 106/107
# Epoch 436 --> loss:0.0566, acc:98.29%, val_loss:1.2276, val_acc:61.54%
#  Epoch 437: iteration 106/107
# Epoch 437 --> loss:0.0656, acc:97.82%, val_loss:1.3858, val_acc:59.44%
#  Epoch 438: iteration 106/107
# Epoch 438 --> loss:0.0631, acc:98.34%, val_loss:1.1748, val_acc:64.34%
#  Epoch 439: iteration 106/107
# Epoch 439 --> loss:0.0608, acc:98.11%, val_loss:1.1976, val_acc:60.84%
#  Epoch 440: iteration 106/107
# Epoch 440 --> loss:0.0543, acc:98.61%, val_loss:1.1935, val_acc:57.34%
#  Epoch 441: iteration 106/107
# Epoch 441 --> loss:0.0560, acc:98.37%, val_loss:1.0103, val_acc:66.43%
#  Epoch 442: iteration 106/107
# Epoch 442 --> loss:0.0424, acc:98.90%, val_loss:1.0938, val_acc:66.43%
#  Epoch 443: iteration 106/107
# Epoch 443 --> loss:0.0617, acc:98.34%, val_loss:1.4616, val_acc:56.64%
#  Epoch 444: iteration 106/107
# Epoch 444 --> loss:0.0642, acc:98.40%, val_loss:1.0953, val_acc:66.43%
#  Epoch 445: iteration 106/107
# Epoch 445 --> loss:0.0655, acc:97.88%, val_loss:1.1400, val_acc:65.73%
#  Epoch 446: iteration 106/107
# Epoch 446 --> loss:0.0582, acc:98.46%, val_loss:1.2458, val_acc:60.84%
#  Epoch 447: iteration 106/107
# Epoch 447 --> loss:0.0708, acc:97.82%, val_loss:1.3287, val_acc:60.14%
#  Epoch 448: iteration 106/107
# Epoch 448 --> loss:0.0570, acc:98.40%, val_loss:1.2136, val_acc:62.94%
#  Epoch 449: iteration 106/107
# Epoch 449 --> loss:0.0512, acc:98.55%, val_loss:1.1032, val_acc:67.13%
#  Epoch 450: iteration 106/107
# Epoch 450 --> loss:0.0497, acc:98.78%, val_loss:1.2107, val_acc:65.73%
#  Epoch 451: iteration 106/107
# Epoch 451 --> loss:0.0629, acc:98.37%, val_loss:1.2052, val_acc:59.44%
#  Epoch 452: iteration 106/107
# Epoch 452 --> loss:0.0703, acc:97.91%, val_loss:1.1018, val_acc:63.64%
#  Epoch 453: iteration 106/107
# Epoch 453 --> loss:0.0646, acc:98.31%, val_loss:1.0490, val_acc:69.23%
#  Epoch 454: iteration 106/107
# Epoch 454 --> loss:0.0604, acc:98.34%, val_loss:1.0846, val_acc:67.83%
#  Epoch 455: iteration 106/107
# Epoch 455 --> loss:0.0579, acc:98.52%, val_loss:1.0642, val_acc:67.83%
#  Epoch 456: iteration 106/107
# Epoch 456 --> loss:0.0652, acc:97.97%, val_loss:1.2331, val_acc:63.64%
#  Epoch 457: iteration 106/107
# Epoch 457 --> loss:0.0634, acc:98.58%, val_loss:1.0872, val_acc:66.43%
#  Epoch 458: iteration 106/107
# Epoch 458 --> loss:0.0568, acc:98.31%, val_loss:1.1333, val_acc:64.34%
#  Epoch 459: iteration 106/107
# Epoch 459 --> loss:0.0603, acc:98.08%, val_loss:1.2402, val_acc:62.94%
#  Epoch 460: iteration 106/107
# Epoch 460 --> loss:0.0446, acc:98.78%, val_loss:1.1191, val_acc:62.24%
#  Epoch 461: iteration 106/107
# Epoch 461 --> loss:0.0482, acc:98.66%, val_loss:1.0715, val_acc:67.13%
#  Epoch 462: iteration 106/107
# Epoch 462 --> loss:0.0652, acc:98.02%, val_loss:1.1700, val_acc:60.84%
#  Epoch 463: iteration 106/107
# Epoch 463 --> loss:0.0677, acc:98.11%, val_loss:1.0987, val_acc:62.24%
#  Epoch 464: iteration 106/107
# Epoch 464 --> loss:0.0740, acc:97.85%, val_loss:1.1992, val_acc:61.54%
#  Epoch 465: iteration 106/107
# Epoch 465 --> loss:0.0647, acc:98.05%, val_loss:0.9846, val_acc:70.63%
#  Epoch 466: iteration 106/107
# Epoch 466 --> loss:0.0534, acc:98.61%, val_loss:1.0556, val_acc:66.43%
#  Epoch 467: iteration 106/107
# Epoch 467 --> loss:0.0545, acc:98.31%, val_loss:1.1006, val_acc:66.43%
#  Epoch 468: iteration 106/107
# Epoch 468 --> loss:0.0618, acc:98.20%, val_loss:1.1558, val_acc:65.03%
#  Epoch 469: iteration 106/107
# Epoch 469 --> loss:0.0625, acc:98.08%, val_loss:1.2243, val_acc:62.24%
#  Epoch 470: iteration 106/107
# Epoch 470 --> loss:0.0491, acc:98.81%, val_loss:1.1983, val_acc:65.73%
#  Epoch 471: iteration 106/107
# Epoch 471 --> loss:0.0519, acc:98.43%, val_loss:1.1089, val_acc:60.84%
#  Epoch 472: iteration 106/107
# Epoch 472 --> loss:0.0566, acc:98.49%, val_loss:1.3634, val_acc:61.54%
#  Epoch 473: iteration 106/107
# Epoch 473 --> loss:0.0729, acc:97.73%, val_loss:1.1941, val_acc:63.64%
#  Epoch 474: iteration 106/107
# Epoch 474 --> loss:0.0637, acc:98.20%, val_loss:1.0445, val_acc:69.23%
#  Epoch 475: iteration 106/107
# Epoch 475 --> loss:0.0598, acc:98.26%, val_loss:1.1127, val_acc:66.43%
#  Epoch 476: iteration 106/107
# Epoch 476 --> loss:0.0501, acc:98.49%, val_loss:1.1463, val_acc:65.03%
#  Epoch 477: iteration 106/107
# Epoch 477 --> loss:0.0539, acc:98.46%, val_loss:1.2745, val_acc:59.44%
#  Epoch 478: iteration 106/107
# Epoch 478 --> loss:0.0614, acc:97.99%, val_loss:1.0662, val_acc:62.94%
#  Epoch 479: iteration 106/107
# Epoch 479 --> loss:0.0583, acc:98.17%, val_loss:1.0840, val_acc:63.64%
#  Epoch 480: iteration 106/107
# Epoch 480 --> loss:0.0592, acc:98.23%, val_loss:1.1799, val_acc:65.03%
#  Epoch 481: iteration 106/107
# Epoch 481 --> loss:0.0484, acc:98.81%, val_loss:1.4966, val_acc:55.94%
#  Epoch 482: iteration 106/107
# Epoch 482 --> loss:0.0656, acc:97.70%, val_loss:1.1359, val_acc:67.13%
#  Epoch 483: iteration 106/107
# Epoch 483 --> loss:0.0667, acc:98.08%, val_loss:1.1336, val_acc:64.34%
#  Epoch 484: iteration 106/107
# Epoch 484 --> loss:0.0472, acc:98.69%, val_loss:1.1576, val_acc:68.53%
#  Epoch 485: iteration 106/107
# Epoch 485 --> loss:0.0467, acc:98.66%, val_loss:0.9820, val_acc:69.23%
#  Epoch 486: iteration 106/107
# Epoch 486 --> loss:0.0691, acc:97.76%, val_loss:1.2161, val_acc:63.64%
#  Epoch 487: iteration 106/107
# Epoch 487 --> loss:0.0837, acc:97.53%, val_loss:1.2976, val_acc:60.84%
#  Epoch 488: iteration 106/107
# Epoch 488 --> loss:0.0658, acc:97.99%, val_loss:1.0717, val_acc:65.73%
#  Epoch 489: iteration 106/107
# Epoch 489 --> loss:0.0610, acc:98.34%, val_loss:1.0087, val_acc:69.23%
#  Epoch 490: iteration 106/107
# Epoch 490 --> loss:0.0655, acc:97.97%, val_loss:1.1648, val_acc:67.83%
#  Epoch 491: iteration 106/107
# Epoch 491 --> loss:0.0539, acc:98.40%, val_loss:1.0831, val_acc:67.13%
#  Epoch 492: iteration 106/107
# Epoch 492 --> loss:0.0556, acc:98.43%, val_loss:1.1818, val_acc:65.73%
#  Epoch 493: iteration 106/107
# Epoch 493 --> loss:0.0487, acc:98.75%, val_loss:1.1579, val_acc:62.24%
#  Epoch 494: iteration 106/107
# Epoch 494 --> loss:0.0538, acc:98.52%, val_loss:1.0195, val_acc:67.83%
#  Epoch 495: iteration 106/107
# Epoch 495 --> loss:0.0529, acc:98.66%, val_loss:1.1497, val_acc:61.54%
#  Epoch 496: iteration 106/107
# Epoch 496 --> loss:0.0483, acc:98.66%, val_loss:1.1818, val_acc:64.34%
#  Epoch 497: iteration 106/107
# Epoch 497 --> loss:0.0541, acc:98.26%, val_loss:1.2257, val_acc:60.14%
#  Epoch 498: iteration 106/107
# Epoch 498 --> loss:0.0540, acc:98.43%, val_loss:1.1161, val_acc:64.34%
#  Epoch 499: iteration 106/107
# Epoch 499 --> loss:0.0537, acc:98.49%, val_loss:1.2268, val_acc:59.44%

# %% [markdown]
# # Save model

# %%
SAVE_PATH = os.path.join('E:/Bhuvan/MODELS/')
os.makedirs('models',exist_ok=True)
torch.save(model.state_dict(),os.path.join(SAVE_PATH,'cnn_attention_lstm_model.pt'))
print('Model is saved to {}'.format(os.path.join(SAVE_PATH,'cnn_attention_lstm_model.pt')))
# Out:
# Model is saved to E:/Bhuvan/MODELS/cnn_attention_lstm_model.pt

# %% [markdown]
# # Load model

# %%
LOAD_PATH = os.path.join('E:/Bhuvan/MODELS/')
model = HybridModel(len(EMOTIONS))
model.load_state_dict(torch.load(os.path.join(LOAD_PATH,'cnn_attention_lstm_model.pt')))
print('Model is loaded from {}'.format(os.path.join(LOAD_PATH,'cnn_attention_lstm_model.pt')))
# Out:
# Model is loaded from E:/Bhuvan/MODELS/cnn_attention_lstm_model.pt

# %% [markdown]
# # Test

# %%
X_test_tensor = torch.tensor(X_test,device=device).float()
Y_test_tensor = torch.tensor(Y_test,dtype=torch.long,device=device)
test_loss, test_acc, predictions = validate(X_test_tensor,Y_test_tensor)
print(f'Test loss is {test_loss:.3f}')
print(f'Test accuracy is {test_acc:.2f}%')
# Out:
# Test loss is 1.346
# Test accuracy is 54.67%

# %% [markdown]
# confusion matrix

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn

predictions = predictions.cpu().numpy()
cm = confusion_matrix(Y_test, predictions)
names = [EMOTIONS[ind] for ind in range(len(EMOTIONS))]
df_cm = pd.DataFrame(cm, index=names, columns=names)
# plt.figure(figsize=(10,7))
sn.set(font_scale=1.4) # for label size
sn.heatmap(df_cm, annot=True, annot_kws={"size": 16}) # font size
plt.show()

# %% [markdown]
# Correlation between emotion intensity and correct prediction

# %%
correct_strong = 0
correct_normal = 0
wrong_strong = 0
wrong_normal = 0
for i in range(len(X_test)):
    intensity = data.loc[test_ind[i],'Emotion intensity']
    if Y_test[i] == predictions[i]: # correct prediction
        if  intensity == 'normal':
            correct_normal += 1
        else:
            correct_strong += 1
    else: # wrong prediction
        if intensity == 'normal':
            wrong_normal += 1
        else:
            wrong_strong += 1
array = np.array([[wrong_normal,wrong_strong],[correct_normal,correct_strong]])
df = pd.DataFrame(array,['wrong','correct'],['normal','strong'])
sn.set(font_scale=1.4) # for label size
sn.heatmap(df, annot=True, annot_kws={"size": 16}) # font size
plt.show()

# %% [markdown]
# correlation between gender and corectness

# %%
correct_male = 0
correct_female = 0
wrong_male = 0
wrong_female = 0
for i in range(len(X_test)):
    gender = data.loc[test_ind[i],'Gender']
    if Y_test[i] == predictions[i]: # correct prediction
        if  gender == 'male':
            correct_male += 1
        else:
            correct_female += 1
    else: # wrong prediction
        if gender == 'male':
            wrong_male += 1
        else:
            wrong_female += 1
array = np.array([[wrong_male,wrong_female],[correct_male,correct_female]])
df = pd.DataFrame(array,['wrong','correct'],['male','female'])
sn.set(font_scale=1.4) # for label size
sn.heatmap(df, annot=True, annot_kws={"size": 16}) # font size
plt.show()

# %% [markdown]
# # Plot loss

# %%
plt.plot(losses,'b')
plt.plot(val_losses,'r')
plt.legend(['train loss','val loss'])
plt.show()

# %%
plt.plot(acc_ep,'b')
plt.plot(vala,'r')
plt.legend(['train accuracy','val accuracy'])
plt.show()
